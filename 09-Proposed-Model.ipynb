# %%
import pandas as pd
import os
import numpy as np
from gensim.models import Word2Vec, FastText
# import glove
# from glove import Corpus
from mittens import GloVe


import collections
import gc 

import keras
from keras import backend as K
from keras import regularizers
from keras.models import Sequential, Model
from keras.layers import Flatten, Dense, Dropout, Input, concatenate, merge, Activation, Concatenate, LSTM, GRU
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv1D, BatchNormalization, GRU, Convolution1D, LSTM
from keras.layers import UpSampling1D, MaxPooling1D, GlobalMaxPooling1D, GlobalAveragePooling1D,MaxPool1D, merge

from keras.optimizers import Adam

from keras.callbacks import EarlyStopping, ModelCheckpoint, History, ReduceLROnPlateau
from keras.utils import np_utils
from keras.backend.tensorflow_backend import set_session, clear_session, get_session
import tensorflow as tf


from sklearn.utils import class_weight
from sklearn.metrics import average_precision_score, roc_auc_score, accuracy_score, f1_score

import warnings
warnings.filterwarnings('ignore')

# %%
type_of_ner = "new"

x_train_lstm = pd.read_pickle("data/"+type_of_ner+"_x_train.pkl")
x_dev_lstm = pd.read_pickle("data/"+type_of_ner+"_x_dev.pkl")
x_test_lstm = pd.read_pickle("data/"+type_of_ner+"_x_test.pkl")

y_train = pd.read_pickle("data/"+type_of_ner+"_y_train.pkl")
y_dev = pd.read_pickle("data/"+type_of_ner+"_y_dev.pkl")
y_test = pd.read_pickle("data/"+type_of_ner+"_y_test.pkl")


ner_word2vec = pd.read_pickle("data/"+type_of_ner+"_ner_word2vec_limited_dict.pkl")
ner_fasttext = pd.read_pickle("data/"+type_of_ner+"_ner_fasttext_limited_dict.pkl")
ner_concat = pd.read_pickle("data/"+type_of_ner+"_ner_combined_limited_dict.pkl")

train_ids = pd.read_pickle("data/"+type_of_ner+"_train_ids.pkl")
dev_ids = pd.read_pickle("data/"+type_of_ner+"_dev_ids.pkl")
test_ids = pd.read_pickle("data/"+type_of_ner+"_test_ids.pkl")

# %%
def make_prediction_cnn(model, test_data):
    probs = model.predict(test_data)
    y_pred = [1 if i>=0.5 else 0 for i in probs]
    return probs, y_pred

def save_scores_cnn(predictions, probs, ground_truth, 
                          
                          embed_name, problem_type, iteration, hidden_unit_size,
                          
                          sequence_name, type_of_ner):
    
    auc = roc_auc_score(ground_truth, probs)
    auprc = average_precision_score(ground_truth, probs)
    acc   = accuracy_score(ground_truth, predictions)
    F1    = f1_score(ground_truth, predictions)
    
    result_dict = {}    
    result_dict['auc'] = auc
    result_dict['auprc'] = auprc
    result_dict['acc'] = acc
    result_dict['F1'] = F1

    result_path = "results/cnn/"
    file_name = str(sequence_name)+"-"+str(hidden_unit_size)+"-"+embed_name
    file_name = file_name +"-"+problem_type+"-"+str(iteration)+"-"+type_of_ner+"-cnn-.p"
    pd.to_pickle(result_dict, os.path.join(result_path, file_name))

    print(auc, auprc, acc, F1)
    
def print_scores_cnn(predictions, probs, ground_truth, model_name, problem_type, iteration, hidden_unit_size):
    auc = roc_auc_score(ground_truth, probs)
    auprc = average_precision_score(ground_truth, probs)
    acc   = accuracy_score(ground_truth, predictions)
    F1    = f1_score(ground_truth, predictions)
    
    print ("AUC: ", auc, "AUPRC: ", auprc, "F1: ", F1)
    
def get_subvector_data(size, embed_name, data):
    if embed_name == "concat":
        vector_size = 200
    else:
        vector_size = 100

    x_data = {}
    for k, v in data.items():
        number_of_additional_vector = len(v) - size
        vector = []
        for i in v:
            vector.append(i)
        if number_of_additional_vector < 0: 
            number_of_additional_vector = np.abs(number_of_additional_vector)

            temp = vector[:size]
            for i in range(0, number_of_additional_vector):
                temp.append(np.zeros(vector_size))
            x_data[k] = np.asarray(temp)
        else:
            x_data[k] = np.asarray(vector[:size])

    return x_data


def proposedmodel(layer_name, number_of_unit, embedding_name, ner_limit, num_filter):
    if embedding_name == "concat":
        input_dimension = 200
    else:
        input_dimension = 100

    sequence_input = Input(shape=(24,104))

    input_img = Input(shape=(ner_limit, input_dimension), name = "cnn_input")

    convs = []
    filter_sizes = [2,3,4]



    text_conv1d = Conv1D(filters=num_filter, kernel_size=3, 
                 padding = 'valid', strides = 1, dilation_rate=1, activation='relu', 
                         kernel_initializer=tf.contrib.layers.xavier_initializer() )(input_img)
    
    text_conv1d = Conv1D(filters=num_filter*2, kernel_size=3, 
                 padding = 'valid', strides = 1, dilation_rate=1, activation='relu',
                        kernel_initializer=tf.contrib.layers.xavier_initializer())(text_conv1d)   
    
    text_conv1d = Conv1D(filters=num_filter*3, kernel_size=3, 
                 padding = 'valid', strides = 1, dilation_rate=1, activation='relu',
                        kernel_initializer=tf.contrib.layers.xavier_initializer())(text_conv1d)   

    
    #concat_conv = keras.layers.Concatenate()([text_conv1d, text_conv1d_2, text_conv1d_3])
    text_embeddings = GlobalMaxPooling1D()(text_conv1d)
    #text_embeddings = Dense(128, activation="relu")(text_embeddings)
    
    if layer_name == "GRU":
        x = GRU(number_of_unit)(sequence_input)
    elif layer_name == "LSTM":
        x = LSTM(number_of_unit)(sequence_input)

    #concatenated = keras.layers.Concatenate()([x, text_embeddings])
    
    # concatenated = merge([x, text_embeddings], mode='concat', concat_axis=1)
    concatenated = keras.layers.concatenate([x, text_embeddings], axis=1)

    concatenated = Dense(512, activation='relu')(concatenated)
    concatenated = Dropout(0.2)(concatenated)
    #concatenated = Dense(256, activation='relu')(concatenated)
    #concatenated = Dense(512, activation='relu')(concatenated)
    
    #concatenated = Dense(512, activation='relu')(concatenated)
    logits_regularizer = tf.contrib.layers.l2_regularizer(scale=0.01)
    preds = Dense(1, activation='sigmoid',use_bias=False,
                         kernel_initializer=tf.contrib.layers.xavier_initializer(), 
                  kernel_regularizer=logits_regularizer)(concatenated)
    
    
    #opt = Adam(lr=1e-4, decay = 0.01)
    
    opt = Adam(lr=1e-3, decay = 0.01)
    
    #opt = Adam(lr=0.001)

    model = Model(inputs=[sequence_input, input_img], outputs=preds)
    model.compile(loss='binary_crossentropy',
                  optimizer=opt,
                  metrics=['acc'])
    
    return model

# %%
embedding_types = ['word2vec', 'fasttext', 'concat']
embedding_dict = [ner_word2vec, ner_fasttext, ner_concat]

target_problems = ['mort_hosp', 'mort_icu', 'los_3', 'los_7']

num_epoch = 100
model_patience = 5
monitor_criteria = 'val_loss'
#monitor_criteria = 'val_acc'
batch_size = 64

filter_number = 32
ner_representation_limit = 64
activation_func = "relu"

sequence_model = "GRU"
sequence_hidden_unit = 256

maxiter = 11
for embed_dict, embed_name in zip(embedding_dict, embedding_types):    
    print ("Embedding: ", embed_name)
    print("=============================")
    
    temp_train_ner = dict((k, embed_dict[k]) for k in train_ids)
    tem_dev_ner = dict((k, embed_dict[k]) for k in dev_ids)
    temp_test_ner = dict((k, embed_dict[k]) for k in test_ids)

    x_train_dict = {}
    x_dev_dict = {}
    x_test_dict = {}

    x_train_dict = get_subvector_data(ner_representation_limit, embed_name, temp_train_ner)
    x_dev_dict = get_subvector_data(ner_representation_limit, embed_name, tem_dev_ner)
    x_test_dict = get_subvector_data(ner_representation_limit, embed_name, temp_test_ner)

    x_train_dict_sorted = collections.OrderedDict(sorted(x_train_dict.items()))
    x_dev_dict_sorted = collections.OrderedDict(sorted(x_dev_dict.items()))
    x_test_dict_sorted = collections.OrderedDict(sorted(x_test_dict.items()))

    # x_train_ner = np.asarray(x_train_dict_sorted.values())
    # x_dev_ner = np.asarray(x_dev_dict_sorted.values())
    # x_test_ner = np.asarray(x_test_dict_sorted.values())

    x_train_ner = np.array(list(x_train_dict_sorted.values())) 
    x_dev_ner = np.array(list(x_dev_dict_sorted.values()))
    x_test_ner = np.array(list(x_test_dict_sorted.values()))

        
    for iteration in range(1,maxiter):
        print ("Iteration number: ", iteration)
    
        for each_problem in target_problems:
            print ("Problem type: ", each_problem)
            print ("__________________")
            
            
            early_stopping_monitor = EarlyStopping(monitor=monitor_criteria, patience=model_patience)
            
            best_model_name = str(ner_representation_limit)+"-basiccnn1d-"+str(embed_name)+"-"+str(each_problem)+"-"+"best_model.hdf5"
            
            checkpoint = ModelCheckpoint(best_model_name, monitor=monitor_criteria, verbose=1,
                save_best_only=True, mode='min')
            
            reduce_lr = ReduceLROnPlateau(monitor=monitor_criteria, factor=0.2,
                              patience=2, min_lr=0.00001, epsilon=1e-4, mode='min')
            

            callbacks = [early_stopping_monitor, checkpoint, reduce_lr]
            
            #model = textCNN(sequence_model, sequence_hidden_unit, embed_name, ner_representation_limit)
            model = proposedmodel(sequence_model, sequence_hidden_unit, 
                               embed_name, ner_representation_limit,filter_number)
            model.fit([x_train_lstm, x_train_ner], y_train[each_problem], epochs=num_epoch, verbose=1, 
                      validation_data=([x_dev_lstm, x_dev_ner], y_dev[each_problem]), callbacks=callbacks, batch_size=batch_size)
            
            
            probs, predictions = make_prediction_cnn(model, [x_test_lstm, x_test_ner])
            print_scores_cnn(predictions, probs, y_test[each_problem], embed_name, each_problem, iteration, sequence_hidden_unit)
            
            model.load_weights(best_model_name)
                      
            probs, predictions = make_prediction_cnn(model, [x_test_lstm, x_test_ner])
            save_scores_cnn(predictions, probs, y_test[each_problem], embed_name, each_problem, iteration,
                            sequence_hidden_unit, sequence_model, type_of_ner)
            del model
            clear_session()
            gc.collect()
# Out:
# Embedding:  word2vec
# =============================
# Iteration number:  1
# Problem type:  mort_hosp
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 11s 740us/step - loss: 0.2780 - acc: 0.9035 - val_loss: 0.2426 - val_acc: 0.9108
#
# Epoch 00001: val_loss improved from inf to 0.24262, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 10s 627us/step - loss: 0.2304 - acc: 0.9162 - val_loss: 0.2343 - val_acc: 0.9094
#
# Epoch 00002: val_loss improved from 0.24262 to 0.23426, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] -
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 13s 857us/step - loss: 0.6603 - acc: 0.6328 - val_loss: 0.6210 - val_acc: 0.6751
#
# Epoch 00001: val_loss improved from inf to 0.62097, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 13s 846us/step - loss: 0.6165 - acc: 0.6711 - val_loss: 0.6170 - val_acc: 0.6798
#
# Epoch 00002: val_loss improved from 0.62097 to 0.61695, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 15s 981us/step - loss: 0.5945 - acc: 0.6960 - val_loss: 0.6149 - val_acc: 0.6687
#
# Epoch 00003: val_loss improved from 0.61695 to 0.61490, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 15s 980us/step - loss: 0.5773 - acc: 0.7045 - val_loss: 0.6228 - val_acc: 0.6604
#
# Epoch 00004: val_loss did not improve from 0.61490
# Epoch 5/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.5585 - acc: 0.7228 - val_loss: 0.6191 - val_acc: 0.6673
#
# Epoch 00005: val_loss did not improve from 0.61490
# Epoch 6/100
# 15219/15219 [==============================] - 15s 991us/step - loss: 0.5378 - acc: 0.7422 - val_loss: 0.6207 - val_acc: 0.6724
#
# Epoch 00006: val_loss did not improve from 0.61490
# Epoch 7/100
# 15219/15219 [==============================] - 15s 1ms/step - loss: 0.5334 - acc: 0.7435 - val_loss: 0.6219 - val_acc: 0.6682
#
# Epoch 00007: val_loss did not improve from 0.61490
# Epoch 8/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.5296 - acc: 0.7493 - val_loss: 0.6214 - val_acc: 0.6719
#
# Epoch 00008: val_loss did not improve from 0.61490
# AUC:  0.6892603574557712 AUPRC:  0.6341289706056719 F1:  0.5621716287215412
# 0.6960508086131216 0.6423426878484161 0.6577736890524379 0.5246006389776358
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 17s 1ms/step - loss: 0.2805 - acc: 0.9204 - val_loss: 0.2606 - val_acc: 0.9247
#
# Epoch 00001: val_loss improved from inf to 0.26056, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 14s 947us/step - loss: 0.2458 - acc: 0.9221 - val_loss: 0.2593 - val_acc: 0.9247
#
# Epoch 00002: val_loss improved from 0.26056 to 0.25933, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 15s 957us/step - loss: 0.2315 - acc: 0.9225 - val_loss: 0.2572 - val_acc: 0.9242
#
# Epoch 00003: val_loss improved from 0.25933 to 0.25719, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 15s 976us/step - loss: 0.2186 - acc: 0.9233 - val_loss: 0.2582 - val_acc: 0.9238
#
# Epoch 00004: val_loss did not improve from 0.25719
# Epoch 5/100
# 15219/15219 [==============================] - 15s 1ms/step - loss: 0.2063 - acc: 0.9250 - val_loss: 0.2627 - val_acc: 0.9224
#
# Epoch 00005: val_loss did not improve from 0.25719
# Epoch 6/100
# 15219/15219 [==============================] - 17s 1ms/step - loss: 0.1931 - acc: 0.9277 - val_loss: 0.2613 - val_acc: 0.9238
#
# Epoch 00006: val_loss did not improve from 0.25719
# Epoch 7/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.1895 - acc: 0.9290 - val_loss: 0.2620 - val_acc: 0.9233
#
# Epoch 00007: val_loss did not improve from 0.25719
# Epoch 8/100
# 15219/15219 [==============================] - 17s 1ms/step - loss: 0.1879 - acc: 0.9287 - val_loss: 0.2621 - val_acc: 0.9238
#
# Epoch 00008: val_loss did not improve from 0.25719
# AUC:  0.7282394845871519 AUPRC:  0.2179158735352554 F1:  0.05263157894736842
# 0.741123398482358 0.22114510846697633 0.9169733210671573 0.026954177897574122
# Iteration number:  2
# Problem type:  mort_hosp
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 18s 1ms/step - loss: 0.2794 - acc: 0.9019 - val_loss: 0.2441 - val_acc: 0.9136
#
# Epoch 00001: val_loss improved from inf to 0.24413, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.2316 - acc: 0.9174 - val_loss: 0.2407 - val_acc: 0.9145
#
# Epoch 00002: val_loss improved from 0.24413 to 0.24074, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 17s 1ms/step - loss: 0.2137 - acc: 0.9227 - val_loss: 0.2358 - val_acc: 0.9104
#
# Epoch 00003: val_loss improved from 0.24074 to 0.23579, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 18s 1ms/step - loss: 0.2014 - acc: 0.9260 - val_loss: 0.2407 - val_acc: 0.9131
#
# Epoch 00004: val_loss did not improve from 0.23579
# Epoch 5/100
# 15219/15219 [==============================] - 19s 1ms/step - loss: 0.1892 - acc: 0.9302 - val_loss: 0.2403 - val_acc: 0.9127
#
# Epoch 00005: val_loss did not improve from 0.23579
# Epoch 6/100
# 15219/15219 [==============================] - 19s 1ms/step - loss: 0.1770 - acc: 0.9351 - val_loss: 0.2404 - val_acc: 0.9117
#
# Epoch 00006: val_loss did not improve from 0.23579
# Epoch 7/100
# 15219/15219 [==============================] - 20s 1ms/step - loss: 0.1736 - acc: 0.9358 - val_loss: 0.2414 - val_acc: 0.9117
#
# Epoch 00007: val_loss did not improve from 0.23579
# Epoch 8/100
# 15219/15219 [==============================] - 20s 1ms/step - loss: 0.1720 - acc: 0.9370 - val_loss: 0.2415 - val_acc: 0.9117
#
# Epoch 00008: val_loss did not improve from 0.23579
# AUC:  0.8730554454136928 AUPRC:  0.5712684116828877 F1:  0.4840055632823366
# 0.8765970570094281 0.5776322559831817 0.9160533578656854 0.47632711621233864
# Problem type:  mort_icu
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 22s 1ms/step - loss: 0.2102 - acc: 0.9315 - val_loss: 0.1755 - val_acc: 0.9418
#
# Epoch 00001: val_loss improved from inf to 0.17551, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 19s 1ms/step - loss: 0.1673 - acc: 0.9434 - val_loss: 0.1714 - val_acc: 0.9432
#
# Epoch 00002: val_loss improved from 0.17551 to 0.17138, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 19s 1ms/step - loss: 0.1524 - acc: 0.9477 - val_loss: 0.1676 - val_acc: 0.9427
#
# Epoch 00003: val_loss improved from 0.17138 to 0.16762, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 20s 1ms/step - loss: 0.1408 - acc: 0.9503 - val_loss: 0.1689 - val_acc: 0.9432
#
# Epoch 00004: val_loss did not improve from 0.16762
# Epoch 5/100
# 15219/15219 [==============================] - 21s 1ms/step - loss: 0.1314 - acc: 0.9535 - val_loss: 0.1690 - val_acc: 0.9436
#
# Epoch 00005: val_loss did not improve from 0.16762
# Epoch 6/100
# 15219/15219 [==============================] - 21s 1ms/step - loss: 0.1203 - acc: 0.9571 - val_loss: 0.1698 - val_acc: 0.9445
#
# Epoch 00006: val_loss did not improve from 0.16762
# Epoch 7/100
# 15219/15219 [==============================] - 22s 1ms/step - loss: 0.1190 - acc: 0.9583 - val_loss: 0.1703 - val_acc: 0.9432
#
# Epoch 00007: val_loss did not improve from 0.16762
# Epoch 8/100
# 15219/15219 [==============================] - 23s 2ms/step - loss: 0.1162 - acc: 0.9578 - val_loss: 0.1704 - val_acc: 0.9441
#
# Epoch 00008: val_loss did not improve from 0.16762
# AUC:  0.8820021224464317 AUPRC:  0.5117081740924668 F1:  0.4388185654008438
# 0.8816322549432714 0.5129535987214878 0.9390524379024839 0.4175824175824176
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 24s 2ms/step - loss: 0.6620 - acc: 0.6315 - val_loss: 0.6229 - val_acc: 0.6756
#
# Epoch 00001: val_loss improved from inf to 0.62290, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 21s 1ms/step - loss: 0.6174 - acc: 0.6709 - val_loss: 0.6177 - val_acc: 0.6779
#
# Epoch 00002: val_loss improved from 0.62290 to 0.61765, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 22s 1ms/step - loss: 0.5985 - acc: 0.6880 - val_loss: 0.6155 - val_acc: 0.6756
#
# Epoch 00003: val_loss improved from 0.61765 to 0.61550, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 22s 1ms/step - loss: 0.5820 - acc: 0.7037 - val_loss: 0.6118 - val_acc: 0.6816
#
# Epoch 00004: val_loss improved from 0.61550 to 0.61181, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 5/100
# 15219/15219 [==============================] - 24s 2ms/step - loss: 0.5664 - acc: 0.7207 - val_loss: 0.6144 - val_acc: 0.6821
#
# Epoch 00005: val_loss did not improve from 0.61181
# Epoch 6/100
# 15219/15219 [==============================] - 25s 2ms/step - loss: 0.5513 - acc: 0.7308 - val_loss: 0.6212 - val_acc: 0.6798
#
# Epoch 00006: val_loss did not improve from 0.61181
# Epoch 7/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.5339 - acc: 0.7433 - val_loss: 0.6166 - val_acc: 0.6798
#
# Epoch 00007: val_loss did not improve from 0.61181
# Epoch 8/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.5300 - acc: 0.7487 - val_loss: 0.6173 - val_acc: 0.6798
#
# Epoch 00008: val_loss did not improve from 0.61181
# Epoch 9/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.5276 - acc: 0.7486 - val_loss: 0.6178 - val_acc: 0.6784
#
# Epoch 00009: val_loss did not improve from 0.61181
# AUC:  0.6961493225949855 AUPRC:  0.6446802618363484 F1:  0.5673842524329106
# 0.699355181209618 0.649406261816267 0.6632934682612696 0.5650623885918004
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.2808 - acc: 0.9188 - val_loss: 0.2620 - val_acc: 0.9247
#
# Epoch 00001: val_loss improved from inf to 0.26199, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 24s 2ms/step - loss: 0.2479 - acc: 0.9221 - val_loss: 0.2602 - val_acc: 0.9247
#
# Epoch 00002: val_loss improved from 0.26199 to 0.26023, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 25s 2ms/step - loss: 0.2338 - acc: 0.9225 - val_loss: 0.2594 - val_acc: 0.9233
#
# Epoch 00003: val_loss improved from 0.26023 to 0.25942, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.2225 - acc: 0.9228 - val_loss: 0.2651 - val_acc: 0.9224
#
# Epoch 00004: val_loss did not improve from 0.25942
# Epoch 5/100
# 15219/15219 [==============================] - 28s 2ms/step - loss: 0.2128 - acc: 0.9248 - val_loss: 0.2627 - val_acc: 0.9228
#
# Epoch 00005: val_loss did not improve from 0.25942
# Epoch 6/100
# 15219/15219 [==============================] - 29s 2ms/step - loss: 0.2012 - acc: 0.9267 - val_loss: 0.2646 - val_acc: 0.9228
#
# Epoch 00006: val_loss did not improve from 0.25942
# Epoch 7/100
# 15219/15219 [==============================] - 27s 2ms/step - loss: 0.1978 - acc: 0.9272 - val_loss: 0.2652 - val_acc: 0.9228
#
# Epoch 00007: val_loss did not improve from 0.25942
# Epoch 8/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 27s 2ms/step - loss: 0.6609 - acc: 0.6316 - val_loss: 0.6222 - val_acc: 0.6714
#
# Epoch 00001: val_loss improved from inf to 0.62217, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 24s 2ms/step - loss: 0.6166 - acc: 0.6715 - val_loss: 0.6144 - val_acc: 0.6784
#
# Epoch 00002: val_loss improved from 0.62217 to 0.61438, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 24s 2ms/step - loss: 0.5955 - acc: 0.6922 - val_loss: 0.6110 - val_acc: 0.6816
#
# Epoch 00003: val_loss improved from 0.61438 to 0.61097, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 24s 2ms/step - loss: 0.5769 - acc: 0.7101 - val_loss: 0.6094 - val_acc: 0.6793
#
# Epoch 00004: val_loss improved from 0.61097 to 0.60941, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 5/100
# 15219/15219 [==============================] - 25s 2ms/step - loss: 0.5584 - acc: 0.7251 - val_loss: 0.6144 - val_acc: 0.6733
#
# Epoch 00005: val_loss did not improve from 0.60941
# Epoch 6/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.5421 - acc: 0.7372 - val_loss: 0.6174 - val_acc: 0.6691
#
# Epoch 00006: val_loss did not improve from 0.60941
# Epoch 7/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.5213 - acc: 0.7560 - val_loss: 0.6163 - val_acc: 0.6765
#
# Epoch 00007: val_loss did not improve from 0.60941
# Epoch 8/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.5186 - acc: 0.7585 - val_loss: 0.6171 - val_acc: 0.6761
#
# Epoch 00008: val_loss did not improve from 0.60941
# Epoch 9/100
# 15219/15219 [==============================] - 22s 1ms/step - loss: 0.5144 - acc: 0.7596 - val_loss: 0.6174 - val_acc: 0.6751
#
# Epoch 00009: val_loss did not improve from 0.60941
# AUC:  0.7024748266024439 AUPRC:  0.647108318927275 F1:  0.5743985743985744
# 0.70376532739444 0.6506400316387073 0.6653633854645814 0.5428840716305372
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 19s 1ms/step - loss: 0.2841 - acc: 0.9192 - val_loss: 0.2605 - val_acc: 0.9247
#
# Epoch 00001: val_loss improved from inf to 0.26053, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 15s 1ms/step - loss: 0.2481 - acc: 0.9218 - val_loss: 0.2552 - val_acc: 0.9247
#
# Epoch 00002: val_loss improved from 0.26053 to 0.25516, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 15s 1ms/step - loss: 0.2339 - acc: 0.9221 - val_loss: 0.2590 - val_acc: 0.9233
#
# Epoch 00003: val_loss did not improve from 0.25516
# Epoch 4/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.2231 - acc: 0.9239 - val_loss: 0.2544 - val_acc: 0.9228
#
# Epoch 00004: val_loss improved from 0.25516 to 0.25441, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 5/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.2128 - acc: 0.9247 - val_loss: 0.2551 - val_acc: 0.9233
#
# Epoch 00005: val_loss did not improve from 0.25441
# Epoch 6/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.2034 - acc: 0.9269 - val_loss: 0.2566 - val_acc: 0.9233
#
# Epoch 00006: val_loss did not improve from 0.25441
# Epoch 7/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.1928 - acc: 0.9286 - val_loss: 0.2568 - val_acc: 0.9238
#
# Epoch 00007: val_loss did not improve from 0.25441
# Epoch 8/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.1894 - acc: 0.9302 - val_loss: 0.2573 - val_acc: 0.9238
#
# Epoch 00008: val_loss did not improve from 0.25441
# Epoch 9/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.1879 - acc: 0.9301 - val_loss: 0.2574 - val_acc: 0.9238
#
# Epoch 00009: val_loss did not improve from 0.25441
# AUC:  0.7311571879714486 AUPRC:  0.21705373144330317 F1:  0.08205128205128205
# 0.7361330807682782 0.22356901918643332 0.9176632934682613 0.0427807486631016
# Iteration number:  4
# Problem type:  mort_hosp
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 18s 1ms/step - loss: 0.2824 - acc: 0.9017 - val_loss: 0.2404 - val_acc: 0.9173
#
# Epoch 00001: val_loss improved from inf to 0.24035, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 15s 997us/step - loss: 0.2314 - acc: 0.9170 - val_loss: 0.2456 - val_acc: 0.9104
#
# Epoch 00002: val_loss did not improve from 0.24035
# Epoch 3/100
# 15219/15219 [==============================] - 15s 1000us/step - loss: 0.2135 - acc: 0.9213 - val_loss: 0.2340 - val_acc: 0.9154
#
# Epoch 00003: val_loss improved from 0.24035 to 0.23400, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 15s 995us/step - loss: 0.1993 - acc: 0.9266 - val_loss: 0.2356 - val_acc: 0.9159
#
# Epoch 00004: val_loss did not improve from 0.23400
# Epoch 5/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.1869 - acc: 0.9311 - val_loss: 0.2357 - val_acc: 0.9164
#
# Epoch 00005: val_loss did not improve from 0.23400
# Epoch 6/100
# 15219/15219 [==============================] - 15s 1ms/step - loss: 0.1727 - acc: 0.9359 - val_loss: 0.2351 - val_acc: 0.9196
#
# Epoch 00006: val_loss did not improve from 0.23400
# Epoch 7/100
# 15219/15219 [==============================] - 15s 995us/step - loss: 0.1695 - acc: 0.9379 - val_loss: 0.2357 - val_acc: 0.9168
#
# Epoch 00007: val_loss did not improve from 0.23400
# Epoch 8/100
# 15219/15219 [==============================] - 15s 999us/step - loss: 0.1669 - acc: 0.9385 - val_loss: 0.2358 - val_acc: 0.9173
#
# Epoch 00008: val_loss did not improve from 0.23400
# AUC:  0.8792344039122391 AUPRC:  0.5732220694881242 F1:  0.47632311977715874
# 0.8836962507709931 0.5817412441000707 0.9142134314627415 0.4783216783216782
# Problem type:  mort_icu
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 17s 1ms/step - loss: 0.2170 - acc: 0.9326 - val_loss: 0.1736 - val_acc: 0.9418
#
# Epoch 00001: val_loss improved from inf to 0.17364, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.1696 - acc: 0.9439 - val_loss: 0.1710 - val_acc: 0.9432
#
# Epoch 00002: val_loss improved from 0.17364 to 0.17098, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.1559 - acc: 0.9466 - val_loss: 0.1691 - val_acc: 0.9422
#
# Epoch 00003: val_loss improved from 0.17098 to 0.16909, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.1455 - acc: 0.9499 - val_loss: 0.1711 - val_acc: 0.9427
#
# Epoch 00004: val_loss did not improve from 0.16909
# Epoch 5/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.1377 - acc: 0.9520 - val_loss: 0.1705 - val_acc: 0.9445
#
# Epoch 00005: val_loss did not improve from 0.16909
# Epoch 6/100
# 15219/15219 [==============================] - 15s 961us/step - loss: 0.1287 - acc: 0.9547 - val_loss: 0.1709 - val_acc: 0.9432
#
# Epoch 00006: val_loss did not improve from 0.16909
# Epoch 7/100
# 15219/15219 [==============================] - 14s 941us/step - loss: 0.1269 - acc: 0.9551 - val_loss: 0.1716 - val_acc: 0.9427
#
# Epoch 00007: val_loss did not improve from 0.16909
# Epoch 8/100
# 15219/15219 [==============================] - 14s 935us/step - loss: 0.1249 - acc: 0.9555 - val_loss: 0.1716 - val_acc: 0.9432
#
# Epoch 00008: val_loss did not improve from 0.16909
# AUC:  0.8879785258361034 AUPRC:  0.5176066703349322 F1:  0.4532224532224532
# 0.8854682647439799 0.5104175599019857 0.9399724011039559 0.42128603104212864
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.6581 - acc: 0.6284 - val_loss: 0.6236 - val_acc: 0.6673
#
# Epoch 00001: val_loss improved from inf to 0.62365, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 15s 1ms/step - loss: 0.6144 - acc: 0.6726 - val_loss: 0.6191 - val_acc: 0.6761
#
# Epoch 00002: val_loss improved from 0.62365 to 0.61911, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 15s 979us/step - loss: 0.5953 - acc: 0.6904 - val_loss: 0.6212 - val_acc: 0.6613
#
# Epoch 00003: val_loss did not improve from 0.61911
# Epoch 4/100
# 15219/15219 [==============================] - 15s 975us/step - loss: 0.5786 - acc: 0.7081 - val_loss: 0.6208 - val_acc: 0.6742
#
# Epoch 00004: val_loss did not improve from 0.61911
# Epoch 5/100
# 15219/15219 [==============================] - 15s 988us/step - loss: 0.5576 - acc: 0.7266 - val_loss: 0.6187 - val_acc: 0.6751
#
# Epoch 00005: val_loss improved from 0.61911 to 0.61867, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 6/100
# 15219/15219 [==============================] - 15s 987us/step - loss: 0.5537 - acc: 0.7278 - val_loss: 0.6180 - val_acc: 0.6747
#
# Epoch 00006: val_loss improved from 0.61867 to 0.61803, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 7/100
# 15219/15219 [==============================] - 15s 1ms/step - loss: 0.5500 - acc: 0.7311 - val_loss: 0.6191 - val_acc: 0.6770
#
# Epoch 00007: val_loss did not improve from 0.61803
# Epoch 8/100
# 15219/15219 [==============================] - 15s 986us/step - loss: 0.5478 - acc: 0.7353 - val_loss: 0.6190 - val_acc: 0.6733
#
# Epoch 00008: val_loss did not improve from 0.61803
# Epoch 9/100
# 15219/15219 [==============================] - 15s 989us/step - loss: 0.5443 - acc: 0.7379 - val_loss: 0.6192 - val_acc: 0.6761
#
# Epoch 00009: val_loss did not improve from 0.61803
# Epoch 10/100
# 15219/15219 [==============================] - 15s 1ms/step - loss: 0.5449 - acc: 0.7349 - val_loss: 0.6193 - val_acc: 0.6756
#
# Epoch 00010: val_loss did not improve from 0.61803
# Epoch 11/100
# 15219/15219 [==============================] - 15s 988us/step - loss: 0.5437 - acc: 0.7375 - val_loss: 0.6193 - val_acc: 0.6756
#
# Epoch 00011: val_loss did not improve from 0.61803
# AUC:  0.6952210468162611 AUPRC:  0.6394380764431273 F1:  0.5679882525697504
# 0.6958505436072734 0.6406199260627263 0.6635234590616376 0.5623691295243793
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.2867 - acc: 0.9158 - val_loss: 0.2602 - val_acc: 0.9247
#
# Epoch 00001: val_loss improved from inf to 0.26015, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 14s 942us/step - loss: 0.2479 - acc: 0.9217 - val_loss: 0.2608 - val_acc: 0.9242
#
# Epoch 00002: val_loss did not improve from 0.26015
# Epoch 3/100
# 15219/15219 [==============================] - 14s 927us/step - loss: 0.2360 - acc: 0.9223 - val_loss: 0.2575 - val_acc: 0.9238
#
# Epoch 00003: val_loss improved from 0.26015 to 0.25751, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] -
saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 14s 901us/step - loss: 0.1710 - acc: 0.9434 - val_loss: 0.1718 - val_acc: 0.9445
#
# Epoch 00002: val_loss improved from 0.17559 to 0.17184, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 13s 872us/step - loss: 0.1564 - acc: 0.9462 - val_loss: 0.1666 - val_acc: 0.9445
#
# Epoch 00003: val_loss improved from 0.17184 to 0.16662, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 14s 907us/step - loss: 0.1451 - acc: 0.9502 - val_loss: 0.1666 - val_acc: 0.9409
#
# Epoch 00004: val_loss did not improve from 0.16662
# Epoch 5/100
# 15219/15219 [==============================] - 14s 915us/step - loss: 0.1358 - acc: 0.9525 - val_loss: 0.1678 - val_acc: 0.9445
#
# Epoch 00005: val_loss did not improve from 0.16662
# Epoch 6/100
# 15219/15219 [==============================] - 14s 926us/step - loss: 0.1260 - acc: 0.9562 - val_loss: 0.1672 - val_acc: 0.9409
#
# Epoch 00006: val_loss did not improve from 0.16662
# Epoch 7/100
# 15219/15219 [==============================] - 14s 931us/step - loss: 0.1235 - acc: 0.9568 - val_loss: 0.1677 - val_acc: 0.9409
#
# Epoch 00007: val_loss did not improve from 0.16662
# Epoch 8/100
# 15219/15219 [==============================] - 15s 982us/step - loss: 0.1220 - acc: 0.9568 - val_loss: 0.1677 - val_acc: 0.9409
#
# Epoch 00008: val_loss did not improve from 0.16662
# AUC:  0.888950403420884 AUPRC:  0.5285734874714287 F1:  0.46021505376344085
# 0.8855205455935827 0.5217432528193997 0.9413523459061638 0.42437923250564336
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.6615 - acc: 0.6264 - val_loss: 0.6227 - val_acc: 0.6779
#
# Epoch 00001: val_loss improved from inf to 0.62273, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 14s 896us/step - loss: 0.6180 - acc: 0.6717 - val_loss: 0.6221 - val_acc: 0.6682
#
# Epoch 00002: val_loss improved from 0.62273 to 0.62206, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 13s 881us/step - loss: 0.5951 - acc: 0.6891 - val_loss: 0.6098 - val_acc: 0.6830
#
# Epoch 00003: val_loss improved from 0.62206 to 0.60979, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 13s 866us/step - loss: 0.5784 - acc: 0.7071 - val_loss: 0.6117 - val_acc: 0.6830
#
# Epoch 00004: val_loss did not improve from 0.60979
# Epoch 5/100
# 15219/15219 [==============================] - 14s 919us/step - loss: 0.5605 - acc: 0.7207 - val_loss: 0.6111 - val_acc: 0.6774
#
# Epoch 00005: val_loss did not improve from 0.60979
# Epoch 6/100
# 15219/15219 [==============================] - 14s 935us/step - loss: 0.5418 - acc: 0.7376 - val_loss: 0.6108 - val_acc: 0.6774
#
# Epoch 00006: val_loss did not improve from 0.60979
# Epoch 7/100
# 15219/15219 [==============================] - 14s 931us/step - loss: 0.5383 - acc: 0.7424 - val_loss: 0.6118 - val_acc: 0.6770
#
# Epoch 00007: val_loss did not improve from 0.60979
# Epoch 8/100
# 15219/15219 [==============================] - 14s 917us/step - loss: 0.5340 - acc: 0.7449 - val_loss: 0.6114 - val_acc: 0.6774
#
# Epoch 00008: val_loss did not improve from 0.60979
# AUC:  0.6968328779894084 AUPRC:  0.6405688488257095 F1:  0.5647407407407408
# 0.6996646424363273 0.6431410235290171 0.6626034958601656 0.5536963796775175
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 16s 1ms/step - loss: 0.2953 - acc: 0.9160 - val_loss: 0.2595 - val_acc: 0.9238
#
# Epoch 00001: val_loss improved from inf to 0.25954, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 14s 937us/step - loss: 0.2497 - acc: 0.9214 - val_loss: 0.2574 - val_acc: 0.9228
#
# Epoch 00002: val_loss improved from 0.25954 to 0.25738, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 14s 952us/step - loss: 0.2394 - acc: 0.9220 - val_loss: 0.2548 - val_acc: 0.9233
#
# Epoch 00003: val_loss improved from 0.25738 to 0.25481, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 14s 927us/step - loss: 0.2295 - acc: 0.9227 - val_loss: 0.2554 - val_acc: 0.9233
#
# Epoch 00004: val_loss did not improve from 0.25481
# Epoch 5/100
# ...
# Epoch 4/100
# 15219/15219 [==============================] - 27s 2ms/step - loss: 0.2025 - acc: 0.9250 - val_loss: 0.2368 - val_acc: 0.9117
#
# Epoch 00004: val_loss did not improve from 0.23618
# Epoch 5/100
# 15219/15219 [==============================] - 29s 2ms/step - loss: 0.1915 - acc: 0.9304 - val_loss: 0.2357 - val_acc: 0.9122
#
# Epoch 00005: val_loss improved from 0.23618 to 0.23567, saving model to 64-basiccnn1d-concat-mort_hosp-best_model.hdf5
# Epoch 6/100
# 15219/15219 [==============================] - 25s 2ms/step - loss: 0.1797 - acc: 0.9348 - val_loss: 0.2382 - val_acc: 0.9117
#
# Epoch 00006: val_loss did not improve from 0.23567
# Epoch 7/100
# 15219/15219 [==============================] - 27s 2ms/step - loss: 0.1708 - acc: 0.9368 - val_loss: 0.2404 - val_acc: 0.9159
#
# Epoch 00007: val_loss did not improve from 0.23567
# Epoch 8/100
# 15219/15219 [==============================] - 28s 2ms/step - loss: 0.1594 - acc: 0.9415 - val_loss: 0.2423 - val_acc: 0.9127
#
# Epoch 00008: val_loss did not improve from 0.23567
# Epoch 9/100
# 15219/15219 [==============================] - 29s 2ms/step - loss: 0.1567 - acc: 0.9424 - val_loss: 0.2437 - val_acc: 0.9117
#
# Epoch 00009: val_loss did not improve from 0.23567
# Epoch 10/100
# 15219/15219 [==============================] - 30s 2ms/step - loss: 0.1545 - acc: 0.9436 - val_loss: 0.2438 - val_acc: 0.9113
#
# Epoch 00010: val_loss did not improve from 0.23567
# AUC:  0.8745049123270773 AUPRC:  0.5607353688676939 F1:  0.46068965517241384
# 0.8781759406115078 0.5662713299810893 0.9126034958601656 0.47075208913649025
# Problem type:  mort_icu
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 27s 2ms/step - loss: 0.2137 - acc: 0.9361 - val_loss: 0.1733 - val_acc: 0.9422
#
# Epoch 00001: val_loss improved from inf to 0.17333, saving model to 64-basiccnn1d-concat-mort_icu-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 27s 2ms/step - loss: 0.1690 - acc: 0.9426 - val_loss: 0.1740 - val_acc: 0.9404
#
# Epoch 00002: val_loss did not improve from 0.17333
# Epoch 3/100
# 15219/15219 [==============================] - 29s 2ms/step - loss: 0.1543 - acc: 0.9466 - val_loss: 0.1689 - val_acc: 0.9409
#
# Epoch 00003: val_loss improved from 0.17333 to 0.16887, saving model to 64-basiccnn1d-concat-mort_icu-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 31s 2ms/step - loss: 0.1429 - acc: 0.9510 - val_loss: 0.1721 - val_acc: 0.9413
#
# Epoch 00004: val_loss did not improve from 0.16887
# Epoch 5/100
# 15219/15219 [==============================] - 33s 2ms/step - loss: 0.1324 - acc: 0.9549 - val_loss: 0.1688 - val_acc: 0.9422
#
# Epoch 00005: val_loss improved from 0.16887 to 0.16877, saving model to 64-basiccnn1d-concat-mort_icu-best_model.hdf5
# Epoch 6/100
# 15219/15219 [==============================] - 32s 2ms/step - loss: 0.1206 - acc: 0.9581 - val_loss: 0.1698 - val_acc: 0.9418
#
# Epoch 00006: val_loss did not improve from 0.16877
# Epoch 7/100
# 15219/15219 [==============================] - 31s 2ms/step - loss: 0.1175 - acc: 0.9590 - val_loss: 0.1707 - val_acc: 0.9418
#
# Epoch 00007: val_loss did not improve from 0.16877
# Epoch 8/100
# 15219/15219 [==============================] - 31s 2ms/step - loss: 0.1151 - acc: 0.9607 - val_loss: 0.1709 - val_acc: 0.9413
#
# Epoch 00008: val_loss did not improve from 0.16877
# Epoch 9/100
# 15219/15219 [==============================] - 36s 2ms/step - loss: 0.1151 - acc: 0.9600 - val_loss: 0.1711 - val_acc: 0.9418
#
# Epoch 00009: val_loss did not improve from 0.16877
# Epoch 10/100
# 15219/15219 [==============================] - 33s 2ms/step - loss: 0.1152 - acc: 0.9597 - val_loss: 0.1711 - val_acc: 0.9418
#
# Epoch 00010: val_loss did not improve from 0.16877
# AUC:  0.8780935437052296 AUPRC:  0.5047996098275394 F1:  0.4658119658119658
# 0.8764615228553148 0.5049256421153866 0.9411223551057958 0.4458874458874459
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 34s 2ms/step - loss: 0.6594 - acc: 0.6335 - val_loss: 0.6208 - val_acc: 0.6724
#
# Epoch 00001: val_loss improved from inf to 0.62079, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 29s 2ms/step - loss: 0.6165 - acc: 0.6740 - val_loss: 0.6157 - val_acc: 0.6747
#
# Epoch 00002: val_loss improved from 0.62079 to 0.61572, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 29s 2ms/step - loss: 0.5976 - acc: 0.6874 - val_loss: 0.6168 - val_acc: 0.6719
#
# Epoch 00003: val_loss did not improve from 0.61572
# Epoch 4/100
# 15219/15219 [==============================] - 28s 2ms/step - loss: 0.5782 - acc: 0.7074 - val_loss: 0.6253 - val_acc: 0.6765
#
# Epoch 00004: val_loss did not improve from 0.61572
# Epoch 5/100
# 15219/15219 [==============================] - 25s 2ms/step - loss: 0.5546 - acc: 0.7255 - val_loss: 0.6192 - val_acc: 0.6738
#
# Epoch 00005: val_loss did not improve from 0.61572
# Epoch 6/100
# 15219/15219 [==============================] - 24s 2ms/step - loss: 0.5501 - acc: 0.7297 - val_loss: 0.6197 - val_acc: 0.6761
#
# Epoch 00006: val_loss did not improve from 0.61572
# Epoch 7/100
# 15219/15219 [==============================] - 24s 2ms/step - loss: 0.5450 - acc: 0.7342 - val_loss: 0.6200 - val_acc: 0.6738
#
# Epoch 00007: val_loss did not improve from 0.61572
# AUC:  0.6977319124876453 AUPRC:  0.6432061786519251 F1:  0.5698421975452952
# 0.6983137168580837 0.6426270479876632 0.6635234590616376 0.5485961123110152
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 24s 2ms/step - loss: 0.2795 - acc: 0.9199 - val_loss: 0.2624 - val_acc: 0.9238
#
# Epoch 00001: val_loss improved from inf to 0.26236, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 22s 1ms/step - loss: 0.2469 - acc: 0.9221 - val_loss: 0.2666 - val_acc: 0.9247
#
# Epoch 00002: val_loss did not improve from 0.26236
# Epoch 3/100
# 15219/15219 [==============================] - 22s 1ms/step - loss: 0.2319 - acc: 0.9223 - val_loss: 0.2588 - val_acc: 0.9247
#
# Epoch 00003: val_loss improved from 0.26236 to 0.25875, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.2193 - acc: 0.9241 - val_loss: 0.2563 - val_acc: 0.9251
#
# Epoch 00004: val_loss improved from 0.25875 to 0.25632, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# Epoch 5/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.2062 - acc: 0.9262 - val_loss: 0.2633 - val_acc: 0.9247
#
# Epoch 00005: val_loss did not improve from 0.25632
# Epoch 6/100
# 15219/15219 [==============================] - 32s 2ms/step - loss: 0.1931 - acc: 0.9301 - val_loss: 0.2614 - val_acc: 0.9224
#
# Epoch 00006: val_loss did not improve from 0.25632
# Epoch 7/100
# 15219/15219 [==============================] - 33s 2ms/step - loss: 0.1789 - acc: 0.9340 - val_loss: 0.2630 - val_acc: 0.9238
#
# Epoch 00007: val_loss did not improve from 0.25632
# Epoch 8/100
# 15219/15219 [==============================] - 32s 2ms/step - loss: 0.1750 - acc: 0.9338 - val_loss: 0.2629 - val_acc: 0.9238
#
# Epoch 00008: val_loss did not improve from 0.25632
# Epoch 9/100
# 15219/15219 [==============================] - 32s 2ms/step - loss: 0.1730 - acc: 0.9358 - val_loss: 0.2636 - val_acc: 0.9238
#
# Epoch 00009: val_loss did not improve from 0.25632
# AUC:  0.709626415752854 AUPRC:  0.2128144206115087 F1:  0.09137055837563453
# 0.7203912741212762 0.2191982821416749 0.9190432382704692 0.048648648648648644
# Iteration number:  10
# Problem type:  mort_hosp
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 34s 2ms/step - loss: 0.2802 - acc: 0.9057 - val_loss: 0.2408 - val_acc: 0.9164
#
# Epoch 00001: val_loss improved from inf to 0.24079, saving model to 64-basiccnn1d-concat-mort_hosp-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 33s 2ms/step - loss: 0.2321 - acc: 0.9165 - val_loss: 0.2356 - val_acc: 0.9131
#
# Epoch 00002: val_loss improved from 0.24079 to 0.23556, saving model to 64-basiccnn1d-concat-mort_hosp-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 32s 2ms/step - loss: 0.2105 - acc: 0.9227 - val_loss: 0.2327 - val_acc: 0.9159
#
# Epoch 00003: val_loss improved from 0.23556 to 0.23268, saving model to 64-basiccnn1d-concat-mort_hosp-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 34s 2ms/step - loss: 0.1940 - acc: 0.9277 - val_loss: 0.2335 - val_acc: 0.9145
#
# Epoch 00004: val_loss did not improve from 0.23268
# Epoch 5/100
# 15219/15219 [==============================] - 34s 2ms/step - loss: 0.1788 - acc: 0.9326 - val_loss: 0.2392 - val_acc: 0.9177
#
# Epoch 00005: val_loss did not improve from 0.23268
# Epoch 6/100
# 15219/15219 [==============================] - 33s 2ms/step - loss: 0.1623 - acc: 0.9390 - val_loss: 0.2375 - val_acc: 0.9168
#
# Epoch 00006: val_loss did not improve from 0.23268
# Epoch 7/100
# 15219/15219 [==============================] - 34s 2ms/step - loss: 0.1583 - acc: 0.9413 - val_loss: 0.2383 - val_acc: 0.9182
#
# Epoch 00007: val_loss did not improve from 0.23268
# Epoch 8/100
# 15219/15219 [==============================] - 35s 2ms/step - loss: 0.1552 - acc: 0.9417 - val_loss: 0.2385 - val_acc: 0.9168
#
# Epoch 00008: val_loss did not improve from 0.23268
# AUC:  0.8772342276852586 AUPRC:  0.5779453529503861 F1:  0.45519203413940257
# 0.8787894307868535 0.5801463266751008 0.9155933762649494 0.4546805349182764
# Problem type:  mort_icu
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 33s 2ms/step - loss: 0.2154 - acc: 0.9325 - val_loss: 0.1809 - val_acc: 0.9441
#
# Epoch 00001: val_loss improved from inf to 0.18091, saving model to 64-basiccnn1d-concat-mort_icu-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 31s 2ms/step - loss: 0.1687 - acc: 0.9439 - val_loss: 0.1729 - val_acc: 0.9390
#
# Epoch 00002: val_loss improved from 0.18091 to 0.17292, saving model to 64-basiccnn1d-concat-mort_icu-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 31s 2ms/step - loss: 0.1530 - acc: 0.9484 - val_loss: 0.1705 - val_acc: 0.9422
#
# Epoch 00003: val_loss improved from 0.17292 to 0.17049, saving model to 64-basiccnn1d-concat-mort_icu-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 31s 2ms/step - loss: 0.1406 - acc: 0.9524 - val_loss: 0.1726 - val_acc: 0.9395
#
# Epoch 00004: val_loss did not improve from 0.17049
# Epoch 5/100
# 15219/15219 [==============================] - 29s 2ms/step - loss: 0.1307 - acc: 0.9555 - val_loss: 0.1748 - val_acc: 0.9399
#
# Epoch 00005: val_loss did not improve from 0.17049
# Epoch 6/100
# 15219/15219 [==============================] - 29s 2ms/step - loss: 0.1184 - acc: 0.9594 - val_loss: 0.1750 - val_acc: 0.9413
#
# Epoch 00006: val_loss did not improve from 0.17049
# Epoch 7/100
# 15219/15219 [==============================] - 28s 2ms/step - loss: 0.1153 - acc: 0.9596 - val_loss: 0.1754 - val_acc: 0.9404
#
# Epoch 00007: val_loss did not improve from 0.17049
# Epoch 8/100
# 15219/15219 [==============================] - 27s 2ms/step - loss: 0.1131 - acc: 0.9620 - val_loss: 0.1756 - val_acc: 0.9404
#
# Epoch 00008: val_loss did not improve from 0.17049
# AUC:  0.8832428172355136 AUPRC:  0.5168952748140466 F1:  0.46025104602510464
# 0.8846380136398396 0.5188285648495308 0.9415823367065317 0.45726495726495725
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.6690 - acc: 0.6305 - val_loss: 0.6276 - val_acc: 0.6645
#
# Epoch 00001: val_loss improved from inf to 0.62760, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 23s 2ms/step - loss: 0.6187 - acc: 0.6701 - val_loss: 0.6177 - val_acc: 0.6761
#
# Epoch 00002: val_loss improved from 0.62760 to 0.61771, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 24s 2ms/step - loss: 0.5985 - acc: 0.6911 - val_loss: 0.6149 - val_acc: 0.6747
#
# Epoch 00003: val_loss improved from 0.61771 to 0.61486, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.5800 - acc: 0.7046 - val_loss: 0.6172 - val_acc: 0.6673
#
# Epoch 00004: val_loss did not improve from 0.61486
# Epoch 5/100
# 15219/15219 [==============================] - 27s 2ms/step - loss: 0.5592 - acc: 0.7282 - val_loss: 0.6215 - val_acc: 0.6701
#
# Epoch 00005: val_loss did not improve from 0.61486
# Epoch 6/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.5370 - acc: 0.7451 - val_loss: 0.6214 - val_acc: 0.6733
#
# Epoch 00006: val_loss did not improve from 0.61486
# Epoch 7/100
# 15219/15219 [==============================] - 25s 2ms/step - loss: 0.5305 - acc: 0.7484 - val_loss: 0.6231 - val_acc: 0.6710
#
# Epoch 00007: val_loss did not improve from 0.61486
# Epoch 8/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.5279 - acc: 0.7519 - val_loss: 0.6227 - val_acc: 0.6705
#
# Epoch 00008: val_loss did not improve from 0.61486
# AUC:  0.6971315490757166 AUPRC:  0.6410357488553946 F1:  0.5590828924162257
# 0.6998958751451274 0.6420771227588393 0.6635234590616376 0.5584062782976156
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 29s 2ms/step - loss: 0.2937 - acc: 0.9179 - val_loss: 0.2648 - val_acc: 0.9242
#
# Epoch 00001: val_loss improved from inf to 0.26483, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 25s 2ms/step - loss: 0.2502 - acc: 0.9222 - val_loss: 0.2575 - val_acc: 0.9247
#
# Epoch 00002: val_loss improved from 0.26483 to 0.25751, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 24s 2ms/step - loss: 0.2374 - acc: 0.9221 - val_loss: 0.2582 - val_acc: 0.9247
#
# Epoch 00003: val_loss did not improve from 0.25751
# Epoch 4/100
# 15219/15219 [==============================] - 25s 2ms/step - loss: 0.2283 - acc: 0.9228 - val_loss: 0.2576 - val_acc: 0.9247
#
# Epoch 00004: val_loss did not improve from 0.25751
# Epoch 5/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.2189 - acc: 0.9235 - val_loss: 0.2567 - val_acc: 0.9242
#
# Epoch 00005: val_loss improved from 0.25751 to 0.25672, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# Epoch 6/100
# 15219/15219 [==============================] - 27s 2ms/step - loss: 0.2159 - acc: 0.9240 - val_loss: 0.2575 - val_acc: 0.9242
#
# Epoch 00006: val_loss did not improve from 0.25672
# Epoch 7/100
# 15219/15219 [==============================] - 26s 2ms/step - loss: 0.2142 - acc: 0.9238 - val_loss: 0.2572 - val_acc: 0.9242
#
# Epoch 00007: val_loss did not improve from 0.25672
# Epoch 8/100
# 15219/15219 [==============================] - 23s 2ms/step - loss: 0.2119 - acc: 0.9239 - val_loss: 0.2573 - val_acc: 0.9242
#
# Epoch 00008: val_loss did not improve from 0.25672
# Epoch 9/100
# 15219/15219 [==============================] - 21s 1ms/step - loss: 0.2116 - acc: 0.9239 - val_loss: 0.2574 - val_acc: 0.9242
#
# Epoch 00009: val_loss did not improve from 0.25672
# Epoch 10/100
# 15219/15219 [==============================] - 19s 1ms/step - loss: 0.2118 - acc: 0.9240 - val_loss: 0.2574 - val_acc: 0.9242
#
# Epoch 00010: val_loss did not improve from 0.25672
# AUC:  0.7277856274346446 AUPRC:  0.22817357915245273 F1:  0.037940379403794036
# 0.7285765350926572 0.22683501405090972 0.9185832566697332 0.032786885245901634
