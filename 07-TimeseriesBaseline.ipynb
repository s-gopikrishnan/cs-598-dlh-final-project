# %%
import pandas as pd
import os
import numpy as np
from gensim.models import Word2Vec, FastText
from mittens import GloVe

# import glove
# from glove import Corpus

import collections
import gc 

import keras
from keras import backend as K
from keras import regularizers
from keras.models import Sequential, Model
from keras.layers import Flatten, Dense, Dropout, Input, concatenate, merge, Activation, Concatenate, LSTM, GRU
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv1D, BatchNormalization, GRU, Convolution1D, LSTM
from keras.layers import UpSampling1D, MaxPooling1D, GlobalMaxPooling1D, GlobalAveragePooling1D,MaxPool1D, merge

from keras.optimizers import Adam


from keras.utils import np_utils
from keras.backend.tensorflow_backend import set_session, clear_session, get_session
import tensorflow as tf

from keras.callbacks import EarlyStopping, ModelCheckpoint, History, ReduceLROnPlateau


from sklearn.utils import class_weight
from sklearn.metrics import average_precision_score, roc_auc_score, accuracy_score, f1_score

import warnings
warnings.filterwarnings('ignore')

# %%
# Reset Keras Session
def reset_keras(model):
    sess = get_session()
    clear_session()
    sess.close()
    sess = get_session()

    try:
        del model # this is from global space - change this as you need
    except:
        pass

    gc.collect() # if it's done something you should see a number being outputted

def make_prediction_timeseries(model, test_data):
    probs = model.predict(test_data)
    y_pred = [1 if i>=0.5 else 0 for i in probs]
    return probs, y_pred

def save_scores_timeseries(predictions, probs, ground_truth, model_name, 
                problem_type, iteration, hidden_unit_size, type_of_ner):
    
    auc = roc_auc_score(ground_truth, probs)
    auprc = average_precision_score(ground_truth, probs)
    acc   = accuracy_score(ground_truth, predictions)
    F1    = f1_score(ground_truth, predictions)
    
    
    result_dict = {}    
    result_dict['auc'] = auc
    result_dict['auprc'] = auprc
    result_dict['acc'] = acc
    result_dict['F1'] = F1

        
    file_name = str(hidden_unit_size)+"-"+model_name+"-"+problem_type+"-"+str(iteration)+"-"+type_of_ner+".p"
    
    result_path = "results/"
    pd.to_pickle(result_dict, os.path.join(result_path, file_name))

    print(auc, auprc, acc, F1)

# %%
def timeseries_model(layer_name, number_of_unit):
    K.clear_session()
    
    sequence_input = Input(shape=(24,104),  name = "timeseries_input")
    
    if layer_name == "LSTM":
        x = LSTM(number_of_unit)(sequence_input)
    else:
        x = GRU(number_of_unit)(sequence_input)
    
    logits_regularizer = tf.contrib.layers.l2_regularizer(scale=0.01)
    sigmoid_pred = Dense(1, activation='sigmoid',use_bias=False,
                         kernel_initializer=tf.contrib.layers.xavier_initializer(), 
                  kernel_regularizer=logits_regularizer)(x)
    
    
    model = Model(inputs=sequence_input, outputs=sigmoid_pred)
    
    
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
    return model

# %%
type_of_ner = "new"

x_train_lstm = pd.read_pickle("data/"+type_of_ner+"_x_train.pkl")
x_dev_lstm = pd.read_pickle("data/"+type_of_ner+"_x_dev.pkl")
x_test_lstm = pd.read_pickle("data/"+type_of_ner+"_x_test.pkl")

y_train = pd.read_pickle("data/"+type_of_ner+"_y_train.pkl")
y_dev = pd.read_pickle("data/"+type_of_ner+"_y_dev.pkl")
y_test = pd.read_pickle("data/"+type_of_ner+"_y_test.pkl")

# %%
from keras.utils.layer_utils import count_params

def countParams(model):
    trainable_count = count_params(model.trainable_weights)
    non_trainable_count = count_params(model.non_trainable_weights)
    print("Trainable count:", trainable_count)
    print("Non-Trainable count:", non_trainable_count)

# %%
epoch_num = 100
model_patience = 3
monitor_criteria = 'val_loss'
batch_size = 128

unit_sizes = [128, 256]
#unit_sizes = [256]
iter_num = 11
target_problems = ['mort_hosp', 'mort_icu', 'los_3', 'los_7']
layers = ["LSTM", "GRU"]
#layers = ["GRU"]
for each_layer in layers:
    print("Layer: ", each_layer)
    for each_unit_size in unit_sizes:
        print("Hidden unit: ", each_unit_size)
        for iteration in range(1, iter_num):
            print("Iteration number: ", iteration)
            print("=============================")

            for each_problem in target_problems:
                print ("Problem type: ", each_problem)
                print ("__________________")


                early_stopping_monitor = EarlyStopping(monitor=monitor_criteria, patience=model_patience)
                best_model_name = str(each_layer)+"-"+str(each_unit_size)+"-"+str(each_problem)+"-"+"best_model.hdf5"
                checkpoint = ModelCheckpoint(best_model_name, monitor='val_loss', verbose=1,
                    save_best_only=True, mode='min', period=1)


                callbacks = [early_stopping_monitor, checkpoint]

                model = timeseries_model(each_layer, each_unit_size)
                model.fit(x_train_lstm, y_train[each_problem], epochs=epoch_num, verbose=1, 
                          validation_data=(x_dev_lstm, y_dev[each_problem]), callbacks=callbacks, batch_size= batch_size)

                model.load_weights(best_model_name)

                probs, predictions = make_prediction_timeseries(model, x_test_lstm)
                save_scores_timeseries(predictions, probs, y_test[each_problem].values,str(each_layer),
                                       each_problem, iteration, each_unit_size,type_of_ner)
                trainable_count = count_params(model.trainable_weights)
                non_trainable_count = count_params(model.non_trainable_weights)
                print("Trainable count:", trainable_count)
                print("Non-Trainable count:", non_trainable_count)
                reset_keras(model)
                #del model
                clear_session()
                gc.collect()
# Out:
# Layer:  LSTM
# Hidden unit:  128
# Iteration number:  1
# =============================
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /Users/Gopikrishnan.Srinivasan@ey.com/opt/anaconda3/envs/py3713/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# 2022-04-23 21:10:41.013876: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-04-23 21:10:41.034143: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fec4b161440 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-04-23 21:10:41.034175: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 15219/15219 [==============================] - 4s 283us/step - loss: 0.2996 - acc: 0.8875 - val_loss: 0.2444 - val_acc: 0.9168
#
# Epoch 00001: val_loss improved from inf to 0.24437, saving model to LSTM-128-mort_hosp-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 4s 245us/step - loss: 0.2322 - acc: 0.9171 - val_loss: 0.2379 - val_acc: 0.9131
#
# Epoch 00002: val_loss improved from 0.24437 to 0.23786, saving model to LSTM-128-mort_hosp-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 5s 312us/step - loss: 0.2116 - acc: 0.9255 - val_loss: 0.2330 - val_acc: 0.9168
#
# Epoch 00003: val_loss improved from 0.23786 to 0.23298, saving model to LSTM-128-mort_hosp-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 5s 359us/step - loss: 0.1914 - acc: 0.9339 - val_loss: 0.2404 - val_acc: 0.9131
#
# Epoch 00004: val_loss did not improve from 0.23298
# Epoch 5/100
# 15219/15219 [==============================] - 6s 417us/step - loss: 0.1713 - acc: 0.9414 - val_loss: 0.2561 - val_acc: 0.9117
#
# Epoch 00005: val_loss did not improve from 0.23298
# Epoch 6/100
# 15219/15219 [==============================] - 7s 463us/step - loss: 0.1515 - acc: 0.9496 - val_loss: 0.2633 - val_acc: 0.9043
#
# Epoch 00006: val_loss did not improve from 0.23298
# 0.871069587628866 0.5533930244032212 0.9132934682612696 0.43137254901960786
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  mort_icu
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 7s 437us/step - loss: 0.2449 - acc: 0.9172 - val_loss: 0.1789 - val_acc: 0.9404
#
# Epoch 00001: val_loss improved from inf to 0.17890, saving model to LSTM-128-mort_icu-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 6s 375us/step - loss: 0.1696 - acc: 0.9436 - val_loss: 0.1766 - val_acc: 0.9432
#
# Epoch 00002: val_loss improved from 0.17890 to 0.17662, saving model to LSTM-128-mort_icu-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 5s 348us/step - loss: 0.1524 - acc: 0.9502 - val_loss: 0.1759 - val_acc: 0.9418
#
# Epoch 00003: val_loss improved from 0.17662 to 0.17592, saving model to LSTM-128-mort_icu-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 5s 332us/step - loss: 0.1336 - acc: 0.9565 - val_loss: 0.1797 - val_acc: 0.9413
#
# Epoch 00004: val_loss did not improve from 0.17592
# Epoch 5/100
# 15219/15219 [==============================] - 5s 347us/step - loss: 0.1172 - acc: 0.9623 - val_loss: 0.1874 - val_acc: 0.9427
#
# Epoch 00005: val_loss did not improve from 0.17592
# Epoch 6/100
# 15219/15219 [==============================] - 6s 368us/step - loss: 0.1016 - acc: 0.9693 - val_loss: 0.1900 - val_acc: 0.9381
#
# Epoch 00006: val_loss did not improve from 0.17592
# 0.8886675406151973 0.4982154248439193 0.9385924563017479 0.42332613390928725
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 7s 474us/step - loss: 0.6511 - acc: 0.6371 - val_loss: 0.6251 - val_acc: 0.6705
#
# Epoch 00001: val_loss improved from inf to 0.62507, saving model to LSTM-128-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 6s 400us/step - loss: 0.6202 - acc: 0.6710 - val_loss: 0.6212 - val_acc: 0.6594
#
# Epoch 00002: val_loss improved from 0.62507 to 0.62118, saving model to LSTM-128-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 6s 410us/step - loss: 0.6004 - acc: 0.6907 - val_loss: 0.6141 - val_acc: 0.6728
#
# Epoch 00003: val_loss improved from 0.62118 to 0.61412, saving model to LSTM-128-los_3-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 6s 418us/step - loss: 0.5749 - acc: 0.7123 - val_loss: 0.6177 - val_acc: 0.6774
#
# Epoch 00004: val_loss did not improve from 0.61412
# Epoch 5/100
# 15219/15219 [==============================] - 6s 408us/step - loss: 0.5419 - acc: 0.7418 - val_loss: 0.6384 - val_acc: 0.6604
#
# Epoch 00005: val_loss did not improve from 0.61412
# Epoch 6/100
# 15219/15219 [==============================] - 6s 374us/step - loss: 0.5033 - acc: 0.7612 - val_loss: 0.6558 - val_acc: 0.6576
#
# Epoch 00006: val_loss did not improve from 0.61412
# 0.6905720069229542 0.6285946597080085 0.6511039558417663 0.5304859176725472
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 7s 439us/step - loss: 0.3062 - acc: 0.9016 - val_loss: 0.2566 - val_acc: 0.9224
#
# Epoch 00001: val_loss improved from inf to 0.25663, saving model to LSTM-128-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 6s 363us/step - loss: 0.2500 - acc: 0.9223 - val_loss: 0.2533 - val_acc: 0.9247
#
# Epoch 00002: val_loss improved from 0.25663 to 0.25327, saving model to LSTM-128-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 6s 384us/step - loss: 0.2375 - acc: 0.9237 - val_loss: 0.2552 - val_acc: 0.9242
#
# Epoch 00003: val_loss did not improve from 0.25327
# Epoch 4/100
# 15219/15219 [==============================] - 5s 350us/step - loss: 0.2247 - acc: 0.9293 - val_loss: 0.2597 - val_acc: 0.9233
#
# Epoch 00004: val_loss did not improve from 0.25327
# Epoch 5/100
# 15219/15219 [==============================] - 5s 325us/step - loss: 0.2063 - acc: 0.9341 - val_loss: 0.2683 - val_acc: 0.9136
#
# Epoch 00005: val_loss did not improve from 0.25327
# 0.733690695998739 0.20725208624184832 0.9176632934682613 0.01648351648351648
# Trainable count: 119424
# Non-Trainable count: 0
# Iteration number:  2
# =============================
# Problem type:  mort_hosp
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 5s 350us/step - loss: 0.3010 - acc: 0.8935 - val_loss: 0.2490 - val_acc: 0.9076
#
# Epoch 00001: val_loss improved from inf to 0.24895, saving model to LSTM-128-mort_hosp-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 5s 318us/step - loss: 0.2331 - acc: 0.9187 - val_loss: 0.2427 - val_acc: 0.9122
#
# Epoch 00002: val_loss improved from 0.24895 to 0.24270, saving model to LSTM-128-mort_hosp-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 5s 339us/step - loss: 0.2105 - acc: 0.9260 - val_loss: 0.2369 - val_acc: 0.9113
#
# Epoch 00003: val_loss improved from 0.24270 to 0.23694, saving model to LSTM-128-mort_hosp-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 5s 353us/step - loss: 0.1899 - acc: 0.9345 - val_loss: 0.2450 - val_acc: 0.9094
#
# Epoch 00004: val_loss did not improve from 0.23694
# Epoch 5/100
# 15219/15219 [==============================] - 6s 365us/step - loss: 0.1687 - acc: 0.9426 - val_loss: 0.2567 - val_acc: 0.9067
#
# Epoch 00005: val_loss did not improve from 0.23694
# Epoch 6/100
# 15219/15219 [==============================] - 6s 365us/step - loss: 0.1480 - acc: 0.9517 - val_loss: 0.2772 - val_acc: 0.9043
#
# Epoch 00006: val_loss did not improve from 0.23694
# 0.8766295488589304 0.5517587049929575 0.9091536338546458 0.4413012729844413
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  mort_icu
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 6s 382us/step - loss: 0.2340 - acc: 0.9190 - val_loss: 0.1783 - val_acc: 0.9390
#
# Epoch 00001: val_loss improved from inf to 0.17830, saving model to LSTM-128-mort_icu-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 5s 325us/step - loss: 0.1696 - acc: 0.9430 - val_loss: 0.1794 - val_acc: 0.9427
#
# Epoch 00002: val_loss did not improve from 0.17830
# Epoch 3/100
# 15219/15219 [==============================] - 5s 320us/step - loss: 0.1497 - acc: 0.9492 - val_loss: 0.1768 - val_acc: 0.9422
#
# Epoch 00003: val_loss improved from 0.17830 to 0.17685, saving model to LSTM-128-mort_icu-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 5s 310us/step - loss: 0.1299 - acc: 0.9581 - val_loss: 0.1882 - val_acc: 0.9307
#
# Epoch 00004: val_loss did not improve from 0.17685
# Epoch 5/100
# 15219/15219 [==============================] - 5s 322us/step - loss: 0.1164 - acc: 0.9619 - val_loss: 0.1904 - val_acc: 0.9335
#
# Epoch 00005: val_loss did not improve from 0.17685
# Epoch 6/100
# 15219/15219 [==============================] - 5s 316us/step - loss: 0.1003 - acc: 0.9687 - val_loss: 0.1967 - val_acc: 0.9385
#
# Epoch 00006: val_loss did not improve from 0.17685
# 0.883291976840364 0.5009172922508304 0.9392824287028518 0.4133333333333333
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 5s 355us/step - loss: 0.6523 - acc: 0.6314 - val_loss: 0.6252 - val_acc: 0.6627
#
# Epoch 00001: val_loss improved from inf to 0.62522, saving model to LSTM-128-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 5s 318us/step - loss: 0.6199 - acc: 0.6713 - val_loss: 0.6198 - val_acc: 0.6659
#
# Epoch 00002: val_loss improved from 0.62522 to 0.61982, saving model to LSTM-128-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] -
saving model to LSTM-128-mort_icu-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 7s 454us/step - loss: 0.1484 - acc: 0.9508 - val_loss: 0.1757 - val_acc: 0.9390
#
# Epoch 00003: val_loss did not improve from 0.17417
# Epoch 4/100
# 15219/15219 [==============================] - 6s 391us/step - loss: 0.1324 - acc: 0.9558 - val_loss: 0.1773 - val_acc: 0.9381
#
# Epoch 00004: val_loss did not improve from 0.17417
# Epoch 5/100
# 15219/15219 [==============================] - 5s 347us/step - loss: 0.1174 - acc: 0.9615 - val_loss: 0.1855 - val_acc: 0.9353
#
# Epoch 00005: val_loss did not improve from 0.17417
# 0.8833426970675905 0.4932882992247606 0.93721251149954 0.3515439429928741
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 5s 353us/step - loss: 0.6523 - acc: 0.6343 - val_loss: 0.6243 - val_acc: 0.6664
#
# Epoch 00001: val_loss improved from inf to 0.62432, saving model to LSTM-128-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 5s 312us/step - loss: 0.6204 - acc: 0.6702 - val_loss: 0.6206 - val_acc: 0.6668
#
# Epoch 00002: val_loss improved from 0.62432 to 0.62061, saving model to LSTM-128-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 5s 344us/step - loss: 0.5998 - acc: 0.6882 - val_loss: 0.6257 - val_acc: 0.6530
#
# Epoch 00003: val_loss did not improve from 0.62061
# Epoch 4/100
# 15219/15219 [==============================] - 5s 342us/step - loss: 0.5747 - acc: 0.7124 - val_loss: 0.6340 - val_acc: 0.6543
#
# Epoch 00004: val_loss did not improve from 0.62061
# Epoch 5/100
# 15219/15219 [==============================] - 6s 364us/step - loss: 0.5427 - acc: 0.7366 - val_loss: 0.6446 - val_acc: 0.6594
#
# Epoch 00005: val_loss did not improve from 0.62061
# 0.6949877639807849 0.6371071764366907 0.6632934682612696 0.568904593639576
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 7s 434us/step - loss: 0.3017 - acc: 0.9022 - val_loss: 0.2564 - val_acc: 0.9242
#
# Epoch 00001: val_loss improved from inf to 0.25641, saving model to LSTM-128-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 6s 371us/step - loss: 0.2501 - acc: 0.9221 - val_loss: 0.2559 - val_acc: 0.9238
#
# Epoch 00002: val_loss improved from 0.25641 to 0.25585, saving model to LSTM-128-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 5s 324us/step - loss: 0.2356 - acc: 0.9240 - val_loss: 0.2572 - val_acc: 0.9233
#
# Epoch 00003: val_loss did not improve from 0.25585
# Epoch 4/100
# 15219/15219 [==============================] - 5s 308us/step - loss: 0.2188 - acc: 0.9288 - val_loss: 0.2592 - val_acc: 0.9219
#
# Epoch 00004: val_loss did not improve from 0.25585
# Epoch 5/100
# 15219/15219 [==============================] - 5s 335us/step - loss: 0.2033 - acc: 0.9332 - val_loss: 0.2671 - val_acc: 0.9191
#
# Epoch 00005: val_loss did not improve from 0.25585
# 0.7248527954785976 0.2148239512583916 0.9185832566697332 0.03804347826086957
# Trainable count: 119424
# Non-Trainable count: 0
# Iteration number:  4
# =============================
# Problem type:  mort_hosp
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 6s 392us/step - loss: 0.3037 - acc: 0.8874 - val_loss: 0.2418 - val_acc: 0.9131
#
# Epoch 00001: val_loss improved from inf to 0.24183, saving model to LSTM-128-mort_hosp-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 5s 353us/step - loss: 0.2336 - acc: 0.9165 - val_loss: 0.2365 - val_acc: 0.9122
#
# Epoch 00002: val_loss improved from 0.24183 to 0.23655, saving model to LSTM-128-mort_hosp-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 6s 374us/step - loss: 0.2102 - acc: 0.9275 - val_loss: 0.2426 - val_acc: 0.9122
#
# Epoch 00003: val_loss did not improve from 0.23655
# Epoch 4/100
# 15219/15219 [==============================] - 6s 384us/step - loss: 0.1938 - acc: 0.9321 - val_loss: 0.2533 - val_acc: 0.9062
#
# Epoch 00004: val_loss did not improve from 0.23655
# Epoch 5/100
# 15219/15219 [==============================] - 6s 401us/step - loss: 0.1695 - acc: 0.9434 - val_loss: 0.2679 - val_acc: 0.9048
#
# Epoch 00005: val_loss did not improve from 0.23655
# 0.8774407436778571 0.5730045728284943 0.9142134314627415 0.4125984251968504
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  mort_icu
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 7s 430us/step - loss: 0.2396 - acc: 0.9169 - val_loss: 0.1790 - val_acc: 0.9390
#
# Epoch 00001: val_loss improved from inf to 0.17904, saving model to LSTM-128-mort_icu-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 6s 380us/step - loss: 0.1692 - acc: 0.9428 - val_loss: 0.1723 - val_acc: 0.9422
#
# Epoch 00002: val_loss improved from 0.17904 to 0.17234, saving model to LSTM-128-mort_icu-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 6s 386us/step - loss: 0.1496 - acc: 0.9498 - val_loss: 0.1810 - val_acc: 0.9390
#
# Epoch 00003: val_loss did not improve from 0.17234
# Epoch 4/100
# 15219/15219 [==============================] - 6s 386us/step - loss: 0.1326 - acc: 0.9566 - val_loss: 0.1875 - val_acc: 0.9381
#
# Epoch 00004: val_loss did not improve from 0.17234
# Epoch 5/100
# 15219/15219 [==============================] - 6s 372us/step - loss: 0.1161 - acc: 0.9620 - val_loss: 0.1825 - val_acc: 0.9353
#
# Epoch 00005: val_loss did not improve from 0.17234
# 0.8849953961639903 0.5028079454173837 0.9402023919043239 0.4247787610619469
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 6s 427us/step - loss: 0.6510 - acc: 0.6343 - val_loss: 0.6220 - val_acc: 0.6742
#
# Epoch 00001: val_loss improved from inf to 0.62202, saving model to LSTM-128-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 6s 377us/step - loss: 0.6202 - acc: 0.6680 - val_loss: 0.6181 - val_acc: 0.6640
#
# Epoch 00002: val_loss improved from 0.62202 to 0.61809, saving model to LSTM-128-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 5s 360us/step - loss: 0.5992 - acc: 0.6910 - val_loss: 0.6185 - val_acc: 0.6677
#
# Epoch 00003: val_loss did not improve from 0.61809
# Epoch 4/100
# 15219/15219 [==============================] - 5s 356us/step - loss: 0.5745 - acc: 0.7127 - val_loss: 0.6263 - val_acc: 0.6553
#
# Epoch 00004: val_loss did not improve from 0.61809
# Epoch 5/100
# 15219/15219 [==============================] - 6s 363us/step - loss: 0.5435 - acc: 0.7351 - val_loss: 0.6418 - val_acc: 0.6617
#
# Epoch 00005: val_loss did not improve from 0.61809
# 0.6888969455270553 0.6283660458172137 0.6580036798528058 0.549803209203754
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 6s 420us/step - loss: 0.3028 - acc: 0.9012 - val_loss: 0.2604 - val_acc: 0.9238
#
# Epoch 00001: val_loss improved from inf to 0.26036, saving model to LSTM-128-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 6s 376us/step - loss: 0.2495 - acc: 0.9217 - val_loss: 0.2542 - val_acc: 0.9233
#
# Epoch 00002: val_loss improved from 0.26036 to 0.25421, saving model to LSTM-128-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] -
saving model to LSTM-128-mort_icu-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 10s 645us/step - loss: 0.1519 - acc: 0.9495 - val_loss: 0.1777 - val_acc: 0.9432
#
# Epoch 00003: val_loss did not improve from 0.17382
# Epoch 4/100
# 15219/15219 [==============================] - 10s 630us/step - loss: 0.1362 - acc: 0.9553 - val_loss: 0.1786 - val_acc: 0.9427
#
# Epoch 00004: val_loss did not improve from 0.17382
# Epoch 5/100
# 15219/15219 [==============================] - 10s 628us/step - loss: 0.1207 - acc: 0.9597 - val_loss: 0.1808 - val_acc: 0.9413
#
# Epoch 00005: val_loss did not improve from 0.17382
# 0.8897194000967585 0.5136933345119993 0.9390524379024839 0.38799076212471134
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 10s 653us/step - loss: 0.6525 - acc: 0.6359 - val_loss: 0.6218 - val_acc: 0.6668
#
# Epoch 00001: val_loss improved from inf to 0.62178, saving model to LSTM-128-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 8s 531us/step - loss: 0.6217 - acc: 0.6692 - val_loss: 0.6234 - val_acc: 0.6631
#
# Epoch 00002: val_loss did not improve from 0.62178
# Epoch 3/100
# 15219/15219 [==============================] - 8s 533us/step - loss: 0.6011 - acc: 0.6899 - val_loss: 0.6204 - val_acc: 0.6664
#
# Epoch 00003: val_loss improved from 0.62178 to 0.62041, saving model to LSTM-128-los_3-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 8s 498us/step - loss: 0.5760 - acc: 0.7102 - val_loss: 0.6299 - val_acc: 0.6617
#
# Epoch 00004: val_loss did not improve from 0.62041
# Epoch 5/100
# 15219/15219 [==============================] - 8s 498us/step - loss: 0.5442 - acc: 0.7371 - val_loss: 0.6421 - val_acc: 0.6645
#
# Epoch 00005: val_loss did not improve from 0.62041
# Epoch 6/100
# 15219/15219 [==============================] - 8s 498us/step - loss: 0.5094 - acc: 0.7597 - val_loss: 0.6873 - val_acc: 0.6474
#
# Epoch 00006: val_loss did not improve from 0.62041
# 0.6887262455059066 0.6311562803070451 0.6520239190432383 0.5638512539636783
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 9s 607us/step - loss: 0.3053 - acc: 0.9007 - val_loss: 0.2607 - val_acc: 0.9238
#
# Epoch 00001: val_loss improved from inf to 0.26066, saving model to LSTM-128-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 8s 521us/step - loss: 0.2517 - acc: 0.9217 - val_loss: 0.2567 - val_acc: 0.9238
#
# Epoch 00002: val_loss improved from 0.26066 to 0.25672, saving model to LSTM-128-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 8s 546us/step - loss: 0.2374 - acc: 0.9240 - val_loss: 0.2580 - val_acc: 0.9219
#
# Epoch 00003: val_loss did not improve from 0.25672
# Epoch 4/100
# 15219/15219 [==============================] - 8s 530us/step - loss: 0.2208 - acc: 0.9292 - val_loss: 0.2658 - val_acc: 0.9201
#
# Epoch 00004: val_loss did not improve from 0.25672
# Epoch 5/100
# 15219/15219 [==============================] - 8s 519us/step - loss: 0.2058 - acc: 0.9339 - val_loss: 0.2721 - val_acc: 0.9201
#
# Epoch 00005: val_loss did not improve from 0.25672
# 0.7246339589290941 0.20566641080918363 0.9185832566697332 0.03804347826086957
# Trainable count: 119424
# Non-Trainable count: 0
# Iteration number:  7
# =============================
# Problem type:  mort_hosp
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 9s 622us/step - loss: 0.3042 - acc: 0.8863 - val_loss: 0.2443 - val_acc: 0.9113
#
# Epoch 00001: val_loss improved from inf to 0.24426, saving model to LSTM-128-mort_hosp-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 8s 507us/step - loss: 0.2342 - acc: 0.9179 - val_loss: 0.2341 - val_acc: 0.9122
#
# Epoch 00002: val_loss improved from 0.24426 to 0.23408, saving model to LSTM-128-mort_hosp-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] -
saving model to LSTM-128-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 10s 684us/step - loss: 0.2366 - acc: 0.9241 - val_loss: 0.2551 - val_acc: 0.9210
#
# Epoch 00003: val_loss did not improve from 0.25508
# Epoch 4/100
# 15219/15219 [==============================] - 10s 669us/step - loss: 0.2200 - acc: 0.9294 - val_loss: 0.2621 - val_acc: 0.9205
#
# Epoch 00004: val_loss did not improve from 0.25508
# Epoch 5/100
# 15219/15219 [==============================] - 10s 650us/step - loss: 0.2065 - acc: 0.9317 - val_loss: 0.2663 - val_acc: 0.9201
#
# Epoch 00005: val_loss did not improve from 0.25508
# 0.7241252167255859 0.2027765029161669 0.9169733210671573 0.032171581769437
# Trainable count: 119424
# Non-Trainable count: 0
# Iteration number:  8
# =============================
# Problem type:  mort_hosp
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 11s 728us/step - loss: 0.2971 - acc: 0.8903 - val_loss: 0.2441 - val_acc: 0.9113
#
# Epoch 00001: val_loss improved from inf to 0.24410, saving model to LSTM-128-mort_hosp-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 9s 610us/step - loss: 0.2316 - acc: 0.9179 - val_loss: 0.2446 - val_acc: 0.9145
#
# Epoch 00002: val_loss did not improve from 0.24410
# Epoch 3/100
# 15219/15219 [==============================] - 10s 628us/step - loss: 0.2090 - acc: 0.9244 - val_loss: 0.2408 - val_acc: 0.9159
#
# Epoch 00003: val_loss improved from 0.24410 to 0.24082, saving model to LSTM-128-mort_hosp-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 10s 654us/step - loss: 0.1895 - acc: 0.9342 - val_loss: 0.2513 - val_acc: 0.9127
#
# Epoch 00004: val_loss did not improve from 0.24082
# Epoch 5/100
# 15219/15219 [==============================] - 10s 650us/step - loss: 0.1706 - acc: 0.9422 - val_loss: 0.2687 - val_acc: 0.9020
#
# Epoch 00005: val_loss did not improve from 0.24082
# Epoch 6/100
# 15219/15219 [==============================] - 11s 693us/step - loss: 0.1505 - acc: 0.9491 - val_loss: 0.2791 - val_acc: 0.8974
#
# Epoch 00006: val_loss did not improve from 0.24082
# 0.8731903691955238 0.552670324834065 0.9123735050597976 0.3884430176565008
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  mort_icu
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 12s 773us/step - loss: 0.2391 - acc: 0.9195 - val_loss: 0.1790 - val_acc: 0.9413
#
# Epoch 00001: val_loss improved from inf to 0.17903, saving model to LSTM-128-mort_icu-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 10s 680us/step - loss: 0.1708 - acc: 0.9438 - val_loss: 0.1729 - val_acc: 0.9441
#
# Epoch 00002: val_loss improved from 0.17903 to 0.17294, saving model to LSTM-128-mort_icu-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 10s 657us/step - loss: 0.1498 - acc: 0.9495 - val_loss: 0.1767 - val_acc: 0.9381
#
# Epoch 00003: val_loss did not improve from 0.17294
# Epoch 4/100
# 15219/15219 [==============================] - 10s 641us/step - loss: 0.1341 - acc: 0.9569 - val_loss: 0.1815 - val_acc: 0.9395
#
# Epoch 00004: val_loss did not improve from 0.17294
# Epoch 5/100
# 15219/15219 [==============================] - 10s 678us/step - loss: 0.1143 - acc: 0.9633 - val_loss: 0.1867 - val_acc: 0.9367
#
# Epoch 00005: val_loss did not improve from 0.17294
# 0.8895773834605241 0.5285875908301826 0.9397424103035878 0.4045454545454545
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 13s 857us/step - loss: 0.6494 - acc: 0.6332 - val_loss: 0.6243 - val_acc: 0.6691
#
# Epoch 00001: val_loss improved from inf to 0.62434, saving model to LSTM-128-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 12s 772us/step - loss: 0.6187 - acc: 0.6757 - val_loss: 0.6137 - val_acc: 0.6738
#
# Epoch 00002: val_loss improved from 0.62434 to 0.61368, saving model to LSTM-128-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 11s 714us/step - loss: 0.5994 - acc: 0.6915 - val_loss: 0.6171 - val_acc: 0.6710
#
# Epoch 00003: val_loss did not improve from 0.61368
# Epoch 4/100
# 15219/15219 [==============================] - 11s 745us/step - loss: 0.5732 - acc: 0.7110 - val_loss: 0.6271 - val_acc: 0.6631
#
# Epoch 00004: val_loss did not improve from 0.61368
# Epoch 5/100
# 15219/15219 [==============================] - 11s 750us/step - loss: 0.5408 - acc: 0.7403 - val_loss: 0.6451 - val_acc: 0.6428
#
# Epoch 00005: val_loss did not improve from 0.61368
# 0.695640567475064 0.6397415004789475 0.6550137994480221 0.5183044315992292
# Trainable count: 119424
# Non-Trainable count: 0
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 12s 817us/step - loss: 0.3045 - acc: 0.9027 - val_loss: 0.2630 - val_acc: 0.9242
#
# Epoch 00001: val_loss improved from inf to 0.26300, saving model to LSTM-128-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 10s 665us/step - loss: 0.2527 - acc: 0.9217 - val_loss: 0.2552 - val_acc: 0.9247
#
# Epoch 00002: val_loss improved from 0.26300 to 0.25524, saving model to LSTM-128-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 10s 660us/step - loss: 0.2404 - acc: 0.9238 - val_loss: 0.2532 - val_acc: 0.9233
#
# Epoch 00003: val_loss improved from 0.25524 to 0.25317, saving model to LSTM-128-los_7-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 10s 639us/step - loss: 0.2252 - acc: 0.9278 - val_loss: 0.2580 - val_acc: 0.9224
#
# Epoch 00004: val_loss did not improve from 0.25317
# Epoch 5/100
# ...
#
# Epoch 00005: val_loss did not improve from 0.17062
# 0.879713469731729 0.5144130801582716 0.9395124195032198 0.44863731656184486
# Trainable count: 277504
# Non-Trainable count: 0
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 13s 869us/step - loss: 0.6535 - acc: 0.6377 - val_loss: 0.6278 - val_acc: 0.6756
#
# Epoch 00001: val_loss improved from inf to 0.62782, saving model to GRU-256-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 12s 795us/step - loss: 0.6292 - acc: 0.6604 - val_loss: 0.6231 - val_acc: 0.6728
#
# Epoch 00002: val_loss improved from 0.62782 to 0.62314, saving model to GRU-256-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 13s 832us/step - loss: 0.6143 - acc: 0.6758 - val_loss: 0.6205 - val_acc: 0.6687
#
# Epoch 00003: val_loss improved from 0.62314 to 0.62053, saving model to GRU-256-los_3-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 13s 839us/step - loss: 0.5980 - acc: 0.6876 - val_loss: 0.6253 - val_acc: 0.6742
#
# Epoch 00004: val_loss did not improve from 0.62053
# Epoch 5/100
# 15219/15219 [==============================] - 13s 822us/step - loss: 0.5807 - acc: 0.7011 - val_loss: 0.6463 - val_acc: 0.6470
#
# Epoch 00005: val_loss did not improve from 0.62053
# Epoch 6/100
# 15219/15219 [==============================] - 12s 767us/step - loss: 0.5576 - acc: 0.7210 - val_loss: 0.6378 - val_acc: 0.6636
#
# Epoch 00006: val_loss did not improve from 0.62053
# 0.6968736647201254 0.6353352220878663 0.6575436982520699 0.5511003919204099
# Trainable count: 277504
# Non-Trainable count: 0
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 13s 838us/step - loss: 0.3178 - acc: 0.8949 - val_loss: 0.2651 - val_acc: 0.9242
#
# Epoch 00001: val_loss improved from inf to 0.26512, saving model to GRU-256-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 11s 722us/step - loss: 0.2549 - acc: 0.9213 - val_loss: 0.2562 - val_acc: 0.9238
#
# Epoch 00002: val_loss improved from 0.26512 to 0.25620, saving model to GRU-256-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 11s 705us/step - loss: 0.2443 - acc: 0.9221 - val_loss: 0.2572 - val_acc: 0.9242
#
# Epoch 00003: val_loss did not improve from 0.25620
# Epoch 4/100
# 15219/15219 [==============================] - 11s 715us/step - loss: 0.2315 - acc: 0.9253 - val_loss: 0.2562 - val_acc: 0.9242
#
# Epoch 00004: val_loss did not improve from 0.25620
# Epoch 5/100
# 15219/15219 [==============================] - 11s 742us/step - loss: 0.2204 - acc: 0.9268 - val_loss: 0.2533 - val_acc: 0.9251
#
# Epoch 00005: val_loss improved from 0.25620 to 0.25327, saving model to GRU-256-los_7-best_model.hdf5
# Epoch 6/100
# 15219/15219 [==============================] - 12s 797us/step - loss: 0.2047 - acc: 0.9332 - val_loss: 0.2712 - val_acc: 0.9201
#
# Epoch 00006: val_loss did not improve from 0.25327
# Epoch 7/100
# 15219/15219 [==============================] - 13s 857us/step - loss: 0.1838 - acc: 0.9397 - val_loss: 0.2811 - val_acc: 0.9145
#
# Epoch 00007: val_loss did not improve from 0.25327
# Epoch 8/100
# 15219/15219 [==============================] - 13s 864us/step - loss: 0.1599 - acc: 0.9487 - val_loss: 0.2991 - val_acc: 0.9159
#
# Epoch 00008: val_loss did not improve from 0.25327
# 0.7232801276710725 0.20910463807094903 0.9169733210671573 0.047493403693931395
# Trainable count: 277504
# Non-Trainable count: 0
# Iteration number:  9
# =============================
# Problem type:  mort_hosp
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 13s 840us/step - loss: 0.3065 - acc: 0.8862 - val_loss: 0.2438 - val_acc: 0.9159
#
# Epoch 00001: val_loss improved from inf to 0.24377, saving model to GRU-256-mort_hosp-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 12s 771us/step - loss: 0.2390 - acc: 0.9135 - val_loss: 0.2363 - val_acc: 0.9159
#
# Epoch 00002: val_loss improved from 0.24377 to 0.23631, saving model to GRU-256-mort_hosp-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 12s 801us/step - loss: 0.2221 - acc: 0.9199 - val_loss: 0.2387 - val_acc: 0.9145
#
# Epoch 00003: val_loss did not improve from 0.23631
# Epoch 4/100
# 15219/15219 [==============================] - 12s 778us/step - loss: 0.2100 - acc: 0.9234 - val_loss: 0.2327 - val_acc: 0.9122
#
# Epoch 00004: val_loss improved from 0.23631 to 0.23275, saving model to GRU-256-mort_hosp-best_model.hdf5
# Epoch 5/100
# 15219/15219 [==============================] - 12s 793us/step - loss: 0.1905 - acc: 0.9311 - val_loss: 0.2352 - val_acc: 0.9127
#
# Epoch 00005: val_loss did not improve from 0.23275
# Epoch 6/100
# 15219/15219 [==============================] - 12s 809us/step - loss: 0.1738 - acc: 0.9397 - val_loss: 0.2565 - val_acc: 0.9034
#
# Epoch 00006: val_loss did not improve from 0.23275
# Epoch 7/100
# 15219/15219 [==============================] - 12s 815us/step - loss: 0.1544 - acc: 0.9472 - val_loss: 0.2677 - val_acc: 0.9011
#
# Epoch 00007: val_loss did not improve from 0.23275
# 0.8719655916820866 0.553653791148489 0.9123735050597976 0.44541484716157204
# Trainable count: 277504
# Non-Trainable count: 0
# Problem type:  mort_icu
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 13s 852us/step - loss: 0.2431 - acc: 0.9175 - val_loss: 0.1847 - val_acc: 0.9413
#
# Epoch 00001: val_loss improved from inf to 0.18474, saving model to GRU-256-mort_icu-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 12s 778us/step - loss: 0.1753 - acc: 0.9426 - val_loss: 0.1734 - val_acc: 0.9427
#
# Epoch 00002: val_loss improved from 0.18474 to 0.17337, saving model to GRU-256-mort_icu-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 12s 784us/step - loss: 0.1566 - acc: 0.9473 - val_loss: 0.1737 - val_acc: 0.9372
#
# Epoch 00003: val_loss did not improve from 0.17337
# Epoch 4/100
# 15219/15219 [==============================] - 11s 754us/step - loss: 0.1459 - acc: 0.9506 - val_loss: 0.1706 - val_acc: 0.9418
#
# Epoch 00004: val_loss improved from 0.17337 to 0.17059, saving model to GRU-256-mort_icu-best_model.hdf5
# Epoch 5/100
# 15219/15219 [==============================] - 12s 769us/step - loss: 0.1305 - acc: 0.9566 - val_loss: 0.1732 - val_acc: 0.9404
#
# Epoch 00005: val_loss did not improve from 0.17059
# Epoch 6/100
# 15219/15219 [==============================] - 12s 799us/step - loss: 0.1153 - acc: 0.9608 - val_loss: 0.1777 - val_acc: 0.9367
#
# Epoch 00006: val_loss did not improve from 0.17059
# Epoch 7/100
# 15219/15219 [==============================] - 12s 814us/step - loss: 0.0984 - acc: 0.9678 - val_loss: 0.2107 - val_acc: 0.9325
#
# Epoch 00007: val_loss did not improve from 0.17059
# 0.8890811055448913 0.5099689275688039 0.9367525298988041 0.43298969072164945
# Trainable count: 277504
# Non-Trainable count: 0
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 14s 946us/step - loss: 0.6525 - acc: 0.6389 - val_loss: 0.6279 - val_acc: 0.6701
#
# Epoch 00001: val_loss improved from inf to 0.62788, saving model to GRU-256-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 13s 874us/step - loss: 0.6282 - acc: 0.6572 - val_loss: 0.6207 - val_acc: 0.6677
#
# Epoch 00002: val_loss improved from 0.62788 to 0.62071, saving model to GRU-256-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 12s 770us/step - loss: 0.6147 - acc: 0.6737 - val_loss: 0.6215 - val_acc: 0.6654
#
# Epoch 00003: val_loss did not improve from 0.62071
# Epoch 4/100
# 15219/15219 [==============================] - 12s 787us/step - loss: 0.5998 - acc: 0.6906 - val_loss: 0.6258 - val_acc: 0.6580
#
# Epoch 00004: val_loss did not improve from 0.62071
# Epoch 5/100
# 15219/15219 [==============================] - 12s 806us/step - loss: 0.5812 - acc: 0.7008 - val_loss: 0.6295 - val_acc: 0.6534
#
# Epoch 00005: val_loss did not improve from 0.62071
# 0.6927742745788608 0.6343920151538465 0.6593836246550138 0.5384855095045186
# Trainable count: 277504
# Non-Trainable count: 0
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 13s 885us/step - loss: 0.3158 - acc: 0.8961 - val_loss: 0.2659 - val_acc: 0.9242
#
# Epoch 00001: val_loss improved from inf to 0.26593, saving model to GRU-256-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 12s 797us/step - loss: 0.2559 - acc: 0.9216 - val_loss: 0.2568 - val_acc: 0.9242
#
# Epoch 00002: val_loss improved from 0.26593 to 0.25681, saving model to GRU-256-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 12s 765us/step - loss: 0.2441 - acc: 0.9223 - val_loss: 0.2559 - val_acc: 0.9242
#
# Epoch 00003: val_loss improved from 0.25681 to 0.25593, saving model to GRU-256-los_7-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 12s 790us/step - loss: 0.2355 - acc: 0.9240 - val_loss: 0.2534 - val_acc: 0.9210
#
# Epoch 00004: val_loss improved from 0.25593 to 0.25338, saving model to GRU-256-los_7-best_model.hdf5
# Epoch 5/100
# 15219/15219 [==============================] - 12s 792us/step - loss: 0.2225 - acc: 0.9269 - val_loss: 0.2600 - val_acc: 0.9242
#
# Epoch 00005: val_loss did not improve from 0.25338
# Epoch 6/100
# 15219/15219 [==============================] - 12s 792us/step - loss: 0.2102 - acc: 0.9312 - val_loss: 0.2658 - val_acc: 0.9173
#
# Epoch 00006: val_loss did not improve from 0.25338
# Epoch 7/100
# 15219/15219 [==============================] - 13s 823us/step - loss: 0.1893 - acc: 0.9376 - val_loss: 0.2774 - val_acc: 0.9177
#
# Epoch 00007: val_loss did not improve from 0.25338
# 0.7200130598275202 0.19947104319575956 0.9160533578656854 0.06649616368286446
# Trainable count: 277504
# Non-Trainable count: 0
# Iteration number:  10
# =============================
# Problem type:  mort_hosp
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 13s 848us/step - loss: 0.3031 - acc: 0.8873 - val_loss: 0.2400 - val_acc: 0.9154
#
# Epoch 00001: val_loss improved from inf to 0.23996, saving model to GRU-256-mort_hosp-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 11s 722us/step - loss: 0.2384 - acc: 0.9133 - val_loss: 0.2328 - val_acc: 0.9191
#
# Epoch 00002: val_loss improved from 0.23996 to 0.23283, saving model to GRU-256-mort_hosp-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 12s 788us/step - loss: 0.2210 - acc: 0.9217 - val_loss: 0.2331 - val_acc: 0.9173
#
# Epoch 00003: val_loss did not improve from 0.23283
# Epoch 4/100
# 15219/15219 [==============================] - 12s 808us/step - loss: 0.2068 - acc: 0.9248 - val_loss: 0.2364 - val_acc: 0.9140
#
# Epoch 00004: val_loss did not improve from 0.23283
# Epoch 5/100
# 15219/15219 [==============================] - 13s 844us/step - loss: 0.1907 - acc: 0.9311 - val_loss: 0.2399 - val_acc: 0.9154
#
# Epoch 00005: val_loss did not improve from 0.23283
# 0.8739894484095516 0.5576770818641951 0.9139834406623735 0.42813455657492355
# Trainable count: 277504
# Non-Trainable count: 0
# Problem type:  mort_icu
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 12s 782us/step - loss: 0.2441 - acc: 0.9164 - val_loss: 0.1811 - val_acc: 0.9390
#
# Epoch 00001: val_loss improved from inf to 0.18110, saving model to GRU-256-mort_icu-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 11s 702us/step - loss: 0.1730 - acc: 0.9435 - val_loss: 0.1723 - val_acc: 0.9441
#
# Epoch 00002: val_loss improved from 0.18110 to 0.17225, saving model to GRU-256-mort_icu-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 11s 733us/step - loss: 0.1588 - acc: 0.9466 - val_loss: 0.1685 - val_acc: 0.9436
#
# Epoch 00003: val_loss improved from 0.17225 to 0.16853, saving model to GRU-256-mort_icu-best_model.hdf5
# Epoch 4/100
# 15219/15219 [==============================] - 12s 758us/step - loss: 0.1463 - acc: 0.9493 - val_loss: 0.1768 - val_acc: 0.9409
#
# Epoch 00004: val_loss did not improve from 0.16853
# Epoch 5/100
# 15219/15219 [==============================] - 12s 778us/step - loss: 0.1328 - acc: 0.9549 - val_loss: 0.1733 - val_acc: 0.9376
#
# Epoch 00005: val_loss did not improve from 0.16853
# Epoch 6/100
# 15219/15219 [==============================] - 11s 721us/step - loss: 0.1186 - acc: 0.9600 - val_loss: 0.1901 - val_acc: 0.9385
#
# Epoch 00006: val_loss did not improve from 0.16853
# 0.8771797993039626 0.4832968288657088 0.9362925482980681 0.3661327231121282
# Trainable count: 277504
# Non-Trainable count: 0
# Problem type:  los_3
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 12s 801us/step - loss: 0.6553 - acc: 0.6362 - val_loss: 0.6319 - val_acc: 0.6701
#
# Epoch 00001: val_loss improved from inf to 0.63188, saving model to GRU-256-los_3-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 11s 726us/step - loss: 0.6294 - acc: 0.6617 - val_loss: 0.6283 - val_acc: 0.6599
#
# Epoch 00002: val_loss improved from 0.63188 to 0.62828, saving model to GRU-256-los_3-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 12s 767us/step - loss: 0.6150 - acc: 0.6737 - val_loss: 0.6288 - val_acc: 0.6534
#
# Epoch 00003: val_loss did not improve from 0.62828
# Epoch 4/100
# 15219/15219 [==============================] - 12s 791us/step - loss: 0.5979 - acc: 0.6905 - val_loss: 0.6232 - val_acc: 0.6590
#
# Epoch 00004: val_loss improved from 0.62828 to 0.62325, saving model to GRU-256-los_3-best_model.hdf5
# Epoch 5/100
# 15219/15219 [==============================] - 12s 805us/step - loss: 0.5811 - acc: 0.7033 - val_loss: 0.6318 - val_acc: 0.6576
#
# Epoch 00005: val_loss did not improve from 0.62325
# Epoch 6/100
# 15219/15219 [==============================] - 12s 820us/step - loss: 0.5560 - acc: 0.7216 - val_loss: 0.6385 - val_acc: 0.6539
#
# Epoch 00006: val_loss did not improve from 0.62325
# Epoch 7/100
# 15219/15219 [==============================] - 12s 779us/step - loss: 0.5212 - acc: 0.7449 - val_loss: 0.6696 - val_acc: 0.6331
#
# Epoch 00007: val_loss did not improve from 0.62325
# 0.6893080498763451 0.6273247606110519 0.656163753449862 0.5358584290592984
# Trainable count: 277504
# Non-Trainable count: 0
# Problem type:  los_7
# __________________
# Train on 15219 samples, validate on 2164 samples
# Epoch 1/100
# 15219/15219 [==============================] - 12s 814us/step - loss: 0.3137 - acc: 0.8999 - val_loss: 0.2591 - val_acc: 0.9233
#
# Epoch 00001: val_loss improved from inf to 0.25906, saving model to GRU-256-los_7-best_model.hdf5
# Epoch 2/100
# 15219/15219 [==============================] - 11s 702us/step - loss: 0.2552 - acc: 0.9205 - val_loss: 0.2584 - val_acc: 0.9242
#
# Epoch 00002: val_loss improved from 0.25906 to 0.25843, saving model to GRU-256-los_7-best_model.hdf5
# Epoch 3/100
# 15219/15219 [==============================] - 11s 720us/step - loss: 0.2433 - acc: 0.9225 - val_loss: 0.2585 - val_acc: 0.9219
#
# Epoch 00003: val_loss did not improve from 0.25843
# Epoch 4/100
# 15219/15219 [==============================] - 11s 740us/step - loss: 0.2339 - acc: 0.9246 - val_loss: 0.2594 - val_acc: 0.9224
#
# Epoch 00004: val_loss did not improve from 0.25843
# Epoch 5/100
# 15219/15219 [==============================] - 12s 768us/step - loss: 0.2208 - acc: 0.9274 - val_loss: 0.2592 - val_acc: 0.9219
#
# Epoch 00005: val_loss did not improve from 0.25843
# 0.7242005077570872 0.20549892835355515 0.9174333026678932 0.021798365122615803
# Trainable count: 277504
# Non-Trainable count: 0
